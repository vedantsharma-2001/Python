# %%
# Pandas Tutorial

# %% [markdown]
# # A Pandas is a powerful data analysis toolkit. It is an open-source. A fast and efficient Dataframe Object for data manipulation. It is used fir reading data structures in different formats csv,tsv,txt,XML,JSON,ZIP etc.

# %%
import pandas as pd

# %% [markdown]
# # To check pandas version

# %%
pd.__version__
# Out:
# '2.2.3'

# %%
l1 = [1,1.1,"data values"]
print(l1)
# Out:
# [1, 1.1, 'data values']

# %% [markdown]
# # A series is like a column in a table. It is a one-dimensional array holding data of any type. In other words, it is a one-dimensional labelled homogenous array.

# %%
s1 = pd.Series(l1)
print(s1)
# Out:
# 0              1
# 1            1.1
# 2    data values
# dtype: object

# %% [markdown]
# # To identify the datatype of Series

# %%
type(s1)
# Out:
# pandas.core.series.Series

# %%
s2 = pd.Series([1,2,1.1,"data values"])
print(s2)
# Out:
# 0              1
# 1              2
# 2            1.1
# 3    data values
# dtype: object

# %% [markdown]
# # Creating an Empty Series

# %%
empty_series = pd.Series([])
print(empty_series)
# Out:
# Series([], dtype: object)

# %% [markdown]
# # If the data values is in list format, then data values should be equal to index values

# %%
s3 = pd.Series([1,2,3,4],index=['a','b','c','d'])
print(s3)
# Out:
# a    1
# b    2
# c    3
# d    4
# dtype: int64

# %% [markdown]
# # To change the datatype into float

# %%
s4 = pd.Series([1,2,3,4],index=['a','b','c','d'],dtype=float,name='data values')
print(s4)
# Out:
# a    1.0
# b    2.0
# c    3.0
# d    4.0
# Name: data values, dtype: float64

# %% [markdown]
# # Printing Scalar Series

# %%
scalar_series = pd.Series(0.5)
print(scalar_series)
# Out:
# 0    0.5
# dtype: float64

# %%
scalar_series = pd.Series(0.5,index=[0,1,2,3])
print(scalar_series)
# Out:
# 0    0.5
# 1    0.5
# 2    0.5
# 3    0.5
# dtype: float64

# %%
dict_series = pd.Series({'a':1,'b':2})
print(dict_series)
# Out:
# a    1
# b    2
# dtype: int64

# %% [markdown]
# # Pandas Series also supports numpy array functions and operators

# %%
s5 = pd.Series([1,2,3,4,5])
print(s5)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
s5[0]
# Out:
# np.int64(1)

# %%
s5[3]
# Out:
# np.int64(4)

# %%
s5[0:3]
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
max(s5)
# Out:
# 5

# %%
min(s5)
# Out:
# 1

# %%
print(s5[s5 > 3])
# Out:
# 3    4
# 4    5
# dtype: int64

# %%
print(s5)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
s6 = pd.Series([1,2,3,4,5])
print(s6)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
print(s5+s6)
# Out:
# 0     2
# 1     4
# 2     6
# 3     8
# 4    10
# dtype: int64

# %%
print(s5-s6)
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# dtype: int64

# %%
print(s5*s6)
# Out:
# 0     1
# 1     4
# 2     9
# 3    16
# 4    25
# dtype: int64

# %%
print(s5/s6)
# Out:
# 0    1.0
# 1    1.0
# 2    1.0
# 3    1.0
# 4    1.0
# dtype: float64

# %% [markdown]
# # Handles Missing Values because of pandas module features. NaN stands for Not a Number.

# %%
s1 = pd.Series([1,2,3,4,5])
s2 = pd.Series([1,2,3])
print(s1+s2)
# Out:
# 0    2.0
# 1    4.0
# 2    6.0
# 3    NaN
# 4    NaN
# dtype: float64

# %% [markdown]
# # A DataFrame is a 2-dimensional data structure, or table with rows and columns or labelled axes. In other words, it is a 2-dimensional labelled heterogenous tabular data structure and also it is size-mutuable.

# %% [markdown]
# # Creating an Empty DataFrame

# %%
emp_df = pd.DataFrame([])
print(emp_df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# # Creating an DataFrame using List

# %%
l = [1,2,3]
print(l)
# Out:
# [1, 2, 3]

# %%
df = pd.DataFrame(l)
df
# Out:
#    0
# 0  1
# 1  2
# 2  3

# %%
d2 = pd.DataFrame([[1,2,3],[4,5,6]])
d2
# Out:
#    0  1  2
# 0  1  2  3
# 1  4  5  6

# %% [markdown]
# # Creating an DataFrame using Dictionary

# %%
dict1 = {'ID':[1,2,3,4]}
print(dict1)
# Out:
# {'ID': [1, 2, 3, 4]}

# %%
df1 = pd.DataFrame(dict1)
df1
# Out:
#    ID
# 0   1
# 1   2
# 2   3
# 3   4

# %%
dict2 = {'ID':[1,2,3,4],'SN':[1,2,3,4]}
print(dict2)
# Out:
# {'ID': [1, 2, 3, 4], 'SN': [1, 2, 3, 4]}

# %%
df2 = pd.DataFrame(dict2)
df2
# Out:
#    ID  SN
# 0   1   1
# 1   2   2
# 2   3   3
# 3   4   4

# %% [markdown]
# # Creating an DataFrame from List of Dictionary

# %%
l1 = [{'a':1,'b':2,'c':3}]
print(l1)
# Out:
# [{'a': 1, 'b': 2, 'c': 3}]

# %%
df3 = pd.DataFrame(l1)
df3
# Out:
#    a  b  c
# 0  1  2  3

# %%
l2 = [{'a':1,'b':2,'c':3},{'a':1,'b':2,'c':3}]
print(l2)
# Out:
# [{'a': 1, 'b': 2, 'c': 3}, {'a': 1, 'b': 2, 'c': 3}]

# %%
df4 = pd.DataFrame(l2)
df4
# Out:
#    a  b  c
# 0  1  2  3
# 1  1  2  3

# %%
l3 = [{'a':1,'b':2},{'a':1,'b':2,'c':3}]
print(l3)
# Out:
# [{'a': 1, 'b': 2}, {'a': 1, 'b': 2, 'c': 3}]

# %% [markdown]
# # Handles Missing Values because of pandas module features. NaN stands for Not a Number.

# %%
df5 = pd.DataFrame(l3)
df5
# Out:
#    a  b    c
# 0  1  2  NaN
# 1  1  2  3.0

# %% [markdown]
# # Creating an DataFrame from Dictionary of Series

# %%
ds1 = {'ID':pd.Series([1,2,3,4]),'SN':pd.Series([1,2,3,4])}
print(ds1)
# Out:
# {'ID': 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64, 'SN': 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64}

# %%
df6 = pd.DataFrame(ds1)
df6
# Out:
#    ID  SN
# 0   1   1
# 1   2   2
# 2   3   3
# 3   4   4

# %% [markdown]
# # The read_csv() function in pandas is used to read data from a CSV (Comma-Separated Values) file into a DataFrame. CSV Format is also used to store tabular data in the form of numbers,plain texts.

# %%
#pd.read_csv()

# %%
pd.read_csv("C:\\Users\\User\\Downloads\\Book1.csv")
# Out:
#    Seat No   Student Name  Age  Percentage
# 0      101  Sanket Shivde   22       82.85
# 1      102     Ayush Jain   22       81.38

# %%
pd.read_csv("C:\\Users\\User\\Downloads\\Book2(1).csv")
# Out:
#   Countries Name        Capital Language Spoken Yes or No
# 0            USA  Washington DC         English       Yes
# 1         France          Paris         English        No
# 2          Japan          Tokyo        Japanese       Yes
# 3         Canada         Ottawa        Canadian       Yes

# %% [markdown]
# # To check the file stored in which directory, we have to import the 'os' module.

# %%
import os

# %% [markdown]
# # In Python, os.getcwd() is a function from the os module that returns the current working directory.

# %%
print(os.getcwd())
# Out:
# G:\Jupyter Notebook

# %% [markdown]
# # Writing CSV Files is used to make some changes in the CSV Files or to do some modifications in the CSV Files. Pandas Library is generally used for Data Preprocessing and Data Cleaning, but mainly used for Data Preprocessing. Data Preprocessing is mainly used for raw data cleaning and to find useful insights.

# %%
df = pd.read_csv("C:\\Users\\User\\Downloads\\Book2(1).csv")
df
# Out:
#   Countries Name        Capital Language Spoken Yes or No
# 0            USA  Washington DC         English       Yes
# 1         France          Paris         English        No
# 2          Japan          Tokyo        Japanese       Yes
# 3         Canada         Ottawa        Canadian       Yes

# %% [markdown]
# # CSV File is in DataFrame Format

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # To identify the column names in the table

# %%
df.columns
# Out:
# Index(['Countries Name', 'Capital', 'Language Spoken', 'Yes or No'], dtype='object')

# %% [markdown]
# # nrows parameter in read_csv() function:-
# # The nrows parameter in the pandas.read_csv() function allows you to specify the number of rows to read from the CSV file.

# %%
pd.read_csv("C:\\Users\\User\\Downloads\\Book2(1).csv",nrows=1)
# Out:
#   Countries Name        Capital Language Spoken Yes or No
# 0            USA  Washington DC         English       Yes

# %%
pd.read_csv("C:\\Users\\User\\Downloads\\Book2(1).csv", nrows = 2)
# Out:
#   Countries Name        Capital Language Spoken Yes or No
# 0            USA  Washington DC         English       Yes
# 1         France          Paris         English        No

# %% [markdown]
# # usecols parameter in read_csv() function:-
# # The usecols parameter in the pd.read_csv() function allows you to specify which columns from a CSV file you want to read into your DataFrame.

# %%
pd.read_csv("C:\\Users\\User\\Downloads\\Book2(1).csv", usecols = [0,1,2])
# Out:
#   Countries Name        Capital Language Spoken
# 0            USA  Washington DC         English
# 1         France          Paris         English
# 2          Japan          Tokyo        Japanese
# 3         Canada         Ottawa        Canadian

# %%
pd.read_csv("C:\\Users\\User\\Downloads\\Book2(1).csv", usecols = [1,2])
# Out:
#          Capital Language Spoken
# 0  Washington DC         English
# 1          Paris         English
# 2          Tokyo        Japanese
# 3         Ottawa        Canadian

# %%
pd.read_csv("C:\\Users\\User\\Downloads\\Book3.csv")
# Out:
#                 0              1                2
# 0  Countries Name        Capital  Language Spoken
# 1             USA  Washington DC          English
# 2          France          Paris           French
# 3           Japan          Tokyo         Japanese
# 4          Canada         Ottawa         Canadian

# %% [markdown]
# # skiprows parameter in read_csv() function:-
# # The skiprows parameter in pandas.read_csv() function allows you to specify the number of rows to skip from the top of the CSV file.

# %%
pd.read_csv("C:\\Users\\User\\Downloads\\Book3.csv",skiprows = 1)
# Out:
#   Countries Name        Capital Language Spoken
# 0            USA  Washington DC         English
# 1         France          Paris          French
# 2          Japan          Tokyo        Japanese
# 3         Canada         Ottawa        Canadian

# %%
pd.read_csv("C:\\Users\\User\\Downloads\\Book3.csv",skiprows = [0])
# Out:
#   Countries Name        Capital Language Spoken
# 0            USA  Washington DC         English
# 1         France          Paris          French
# 2          Japan          Tokyo        Japanese
# 3         Canada         Ottawa        Canadian

# %%
pd.read_csv("C:\\Users\\User\\Downloads\\Book3.csv",skiprows = 3)
# Out:
#    France   Paris    French
# 0   Japan   Tokyo  Japanese
# 1  Canada  Ottawa  Canadian

# %%
pd.read_csv("C:\\Users\\User\\Downloads\\Book3.csv",skiprows = [0,1,2])
# Out:
#    France   Paris    French
# 0   Japan   Tokyo  Japanese
# 1  Canada  Ottawa  Canadian

# %%
pd.read_csv("C:\\Users\\User\\Downloads\\Book2(1).csv")
# Out:
#   Countries Name        Capital Language Spoken Yes or No
# 0            USA  Washington DC         English       Yes
# 1         France          Paris         English        No
# 2          Japan          Tokyo        Japanese       Yes
# 3         Canada         Ottawa        Canadian       Yes

# %% [markdown]
# # index_col parameter in read_csv() function:-
# # The index_col parameter in read_csv() function allows you to specify which column to use as the index for the DataFrame.

# %%
pd.read_csv("C:\\Users\\User\\Downloads\\Book2(1).csv",index_col = 'Countries Name')
# Out:
#                       Capital Language Spoken Yes or No
# Countries Name
# USA             Washington DC         English       Yes
# France                  Paris         English        No
# Japan                   Tokyo        Japanese       Yes
# Canada                 Ottawa        Canadian       Yes

# %%
pd.read_csv("C:\\Users\\User\\Downloads\\Book2(1).csv",index_col = 0)
# Out:
#                       Capital Language Spoken Yes or No
# Countries Name
# USA             Washington DC         English       Yes
# France                  Paris         English        No
# Japan                   Tokyo        Japanese       Yes
# Canada                 Ottawa        Canadian       Yes

# %%
pd.read_csv("C:\\Users\\User\\Downloads\\Book2(1).csv",index_col = 'Capital')
# Out:
#               Countries Name Language Spoken Yes or No
# Capital
# Washington DC            USA         English       Yes
# Paris                 France         English        No
# Tokyo                  Japan        Japanese       Yes
# Ottawa                Canada        Canadian       Yes

# %%
pd.read_csv("C:\\Users\\User\\Downloads\\Book2(1).csv",index_col = 1)
# Out:
#               Countries Name Language Spoken Yes or No
# Capital
# Washington DC            USA         English       Yes
# Paris                 France         English        No
# Tokyo                  Japan        Japanese       Yes
# Ottawa                Canada        Canadian       Yes

# %%
pd.read_csv("C:\\Users\\User\\Downloads\\Book2(1).csv",index_col = 'Language Spoken')
# Out:
#                 Countries Name        Capital Yes or No
# Language Spoken
# English                    USA  Washington DC       Yes
# English                 France          Paris        No
# Japanese                 Japan          Tokyo       Yes
# Canadian                Canada         Ottawa       Yes

# %%
pd.read_csv("C:\\Users\\User\\Downloads\\Book2(1).csv",index_col = 2)
# Out:
#                 Countries Name        Capital Yes or No
# Language Spoken
# English                    USA  Washington DC       Yes
# English                 France          Paris        No
# Japanese                 Japan          Tokyo       Yes
# Canadian                Canada         Ottawa       Yes

# %%
pd.read_csv("C:\\Users\\User\\Downloads\\Book3.csv")
# Out:
#                 0              1                2
# 0  Countries Name        Capital  Language Spoken
# 1             USA  Washington DC          English
# 2          France          Paris           French
# 3           Japan          Tokyo         Japanese
# 4          Canada         Ottawa         Canadian

# %% [markdown]
# # header parameter in read_csv() function:-
# # The header parameter in the pandas.read_csv() function is used to specify which row (or rows) in your CSV file should be used as the header (column names) for the resulting DataFrame.

# %%
pd.read_csv("C:\\Users\\User\\Downloads\\Book3.csv",header = 1)
# Out:
#   Countries Name        Capital Language Spoken
# 0            USA  Washington DC         English
# 1         France          Paris          French
# 2          Japan          Tokyo        Japanese
# 3         Canada         Ottawa        Canadian

# %%
pd.read_csv("C:\\Users\\User\\Downloads\\Book3.csv",header = 1)
# Out:
#   Countries Name        Capital Language Spoken
# 0            USA  Washington DC         English
# 1         France          Paris          French
# 2          Japan          Tokyo        Japanese
# 3         Canada         Ottawa        Canadian

# %%
pd.read_csv("C:\\Users\\User\\Downloads\\Book4.csv")
# Out:
#        Unnamed: 0           Data       Unnamed: 2
# 0               0              1                2
# 1  Countries Name        Capital  Language Spoken
# 2             USA  Washington DC          English
# 3          France          Paris           French
# 4           Japan          Tokyo         Japanese
# 5          Canada         Ottawa         Canadian

# %%
pd.read_csv("C:\\Users\\User\\Downloads\\Book4.csv",header = 2)
# Out:
#   Countries Name        Capital Language Spoken
# 0            USA  Washington DC         English
# 1         France          Paris          French
# 2          Japan          Tokyo        Japanese
# 3         Canada         Ottawa        Canadian

# %%
pd.read_csv("C:\\Users\\User\\Downloads\\Book5.csv")
# Out:
#       USA Washington DC   English
# 0  France         Paris    French
# 1   Japan         Tokyo  Japanese
# 2  Canada        Ottawa  Canadian

# %%
pd.read_csv("C:\\Users\\User\\Downloads\\Book5.csv",header = None)
# Out:
#         0              1         2
# 0     USA  Washington DC   English
# 1  France          Paris    French
# 2   Japan          Tokyo  Japanese
# 3  Canada         Ottawa  Canadian

# %% [markdown]
# # prefix parameter in read_csv() function:-
# # The prefix parameter in the pandas.read_csv() function is used to add a prefix to the column names when the CSV file does not have a header row.

# %%
#pd.read_csv("C:\\Users\\User\\Downloads\\Book5.csv",header = None, prefix = 'Columns')

# %% [markdown]
# # names parameter in read_csv() function:-
# # The names parameter in the pd.read_csv() function is used to specify the column names for the DataFrame that is created.

# %%
pd.read_csv("C:\\Users\\User\\Downloads\\Book5.csv",names = ['Country Name','Capital','Language Spoken'])
# Out:
#   Country Name        Capital Language Spoken
# 0          USA  Washington DC         English
# 1       France          Paris          French
# 2        Japan          Tokyo        Japanese
# 3       Canada         Ottawa        Canadian

# %%
pd.read_csv("C:\\Users\\User\\Downloads\\Book2(1).csv")
# Out:
#   Countries Name        Capital Language Spoken Yes or No
# 0            USA  Washington DC         English       Yes
# 1         France          Paris         English        No
# 2          Japan          Tokyo        Japanese       Yes
# 3         Canada         Ottawa        Canadian       Yes

# %% [markdown]
# # In pandas, the head() function is used to return the first few rows of a DataFrame or Series. By default, it returns first 5 rows, if a number is not specified.

# %%
pd.read_csv("C:\\Users\\User\\Downloads\\fr.1.csv").head()
# Out:
#        Round             Date                 Team 1   FT            Team 2
# 0  Journée 1  Fri Aug 21 2020  Girondins de Bordeaux  0-0         FC Nantes
# 1  Journée 1  Sat Aug 22 2020              Dijon FCO  0-1        Angers SCO
# 2  Journée 1  Sat Aug 22 2020              Lille OSC  1-1  Stade Rennais FC
# 3  Journée 1  Sun Aug 23 2020              AS Monaco  2-2    Stade de Reims
# 4  Journée 1  Sun Aug 23 2020             FC Lorient  3-1     RC Strasbourg

# %%
pd.read_csv("C:\\Users\\User\\Downloads\\fr.1.csv").head(1)
# Out:
#        Round             Date                 Team 1   FT     Team 2
# 0  Journée 1  Fri Aug 21 2020  Girondins de Bordeaux  0-0  FC Nantes

# %%
pd.read_csv("C:\\Users\\User\\Downloads\\fr.1.csv").head(6)
# Out:
#        Round             Date                 Team 1   FT             Team 2
# 0  Journée 1  Fri Aug 21 2020  Girondins de Bordeaux  0-0          FC Nantes
# 1  Journée 1  Sat Aug 22 2020              Dijon FCO  0-1         Angers SCO
# 2  Journée 1  Sat Aug 22 2020              Lille OSC  1-1   Stade Rennais FC
# 3  Journée 1  Sun Aug 23 2020              AS Monaco  2-2     Stade de Reims
# 4  Journée 1  Sun Aug 23 2020             FC Lorient  3-1      RC Strasbourg
# 5  Journée 1  Sun Aug 23 2020        Nîmes Olympique  4-0  Stade Brestois 29

# %% [markdown]
# # In pandas, the tail() function is used to return the last few rows of a DataFrame or Series. By default, it returns last 5 rows, if a number is not specified.

# %%
pd.read_csv("C:\\Users\\User\\Downloads\\fr.1.csv").tail()
# Out:
#           Round             Date            Team 1   FT                 Team 2
# 375  Journée 38  Sun May 23 2021         FC Nantes  NaN        Montpellier HSC
# 376  Journée 38  Sun May 23 2021    Stade de Reims  NaN  Girondins de Bordeaux
# 377  Journée 38  Sun May 23 2021  Stade Rennais FC  NaN        Nîmes Olympique
# 378  Journée 38  Sun May 23 2021  AS Saint-Étienne  NaN              Dijon FCO
# 379  Journée 38  Sun May 23 2021     RC Strasbourg  NaN             FC Lorient

# %%
pd.read_csv("C:\\Users\\User\\Downloads\\fr.1.csv").tail(1)
# Out:
#           Round             Date         Team 1   FT      Team 2
# 379  Journée 38  Sun May 23 2021  RC Strasbourg  NaN  FC Lorient

# %%
pd.read_csv("C:\\Users\\User\\Downloads\\fr.1.csv").tail(5)
# Out:
#           Round             Date            Team 1   FT                 Team 2
# 375  Journée 38  Sun May 23 2021         FC Nantes  NaN        Montpellier HSC
# 376  Journée 38  Sun May 23 2021    Stade de Reims  NaN  Girondins de Bordeaux
# 377  Journée 38  Sun May 23 2021  Stade Rennais FC  NaN        Nîmes Olympique
# 378  Journée 38  Sun May 23 2021  AS Saint-Étienne  NaN              Dijon FCO
# 379  Journée 38  Sun May 23 2021     RC Strasbourg  NaN             FC Lorient

# %%
pd.read_csv("C:\\Users\\User\\Downloads\\Book1.csv")
# Out:
#    Seat No   Student Name  Age  Percentage
# 0      101  Sanket Shivde   22       82.85
# 1      102     Ayush Jain   22       81.38

# %% [markdown]
# # dtype parameter in read_csv() function:-
# # The dtype parameter in the read_csv() function in pandas allows you to specify the data type of each column in the CSV file.

# %%
pd.read_csv("C:\\Users\\User\\Downloads\\Book1.csv",dtype = {"Seat No":"float64","Age":"float64"})
# Out:
#    Seat No   Student Name   Age  Percentage
# 0    101.0  Sanket Shivde  22.0       82.85
# 1    102.0     Ayush Jain  22.0       81.38

# %%
pd.read_csv("C:\\Users\\User\\Downloads\\Book2(1).csv")
# Out:
#   Countries Name        Capital Language Spoken Yes or No
# 0            USA  Washington DC         English       Yes
# 1         France          Paris         English        No
# 2          Japan          Tokyo        Japanese       Yes
# 3         Canada         Ottawa        Canadian       Yes

# %% [markdown]
# # true_values parameter in read_csv() function:-
# # The true_values parameter in the pandas.read_csv() function allows you to specify a list of values that should be interpreted as True when reading the CSV file.
# # false_values parameter in read_csv() function:-
# # The false_values parameter in the pandas.read_csv() function allows you to specify a list of values that should be interpreted as False when reading the CSV file.

# %%
pd.read_csv("C:\\Users\\User\\Downloads\\Book2(1).csv",true_values=['Yes'],false_values=['No'])
# Out:
#   Countries Name        Capital Language Spoken  Yes or No
# 0            USA  Washington DC         English       True
# 1         France          Paris         English      False
# 2          Japan          Tokyo        Japanese       True
# 3         Canada         Ottawa        Canadian       True

# %%
pd.read_csv("C:\\Users\\User\\Downloads\\countries of the world.csv")
# Out:
#                Country                               Region  Population  \
# 0         Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1             Albania                             no values     3581655
# 2             Algeria                                   NaN    32930091
# 3      American Samoa                         not available       57794
# 4             Andorra   WESTERN EUROPE                            71201
# 5              Angola   SUB-SAHARAN AFRICA                     12127071
# 6            Anguilla               LATIN AMER. & CARIB           13477
# 7   Antigua & Barbuda               LATIN AMER. & CARIB           69108
# 8           Argentina               LATIN AMER. & CARIB        39921833
# 9             Armenia                  C.W. OF IND. STATES      2976372
# 10              Aruba               LATIN AMER. & CARIB           71891
# 11          Australia   OCEANIA                                20264082
# 12            Austria   WESTERN EUROPE                          8192880
# 13         Azerbaijan                  C.W. OF IND. STATES      7961619
# 14       Bahamas, The               LATIN AMER. & CARIB          303770
# 15            Bahrain   NEAR EAST                                698585
# 16         Bangladesh         ASIA (EX. NEAR EAST)            147365352
# 17           Barbados               LATIN AMER. & CARIB          279912
# 18            Belarus                  C.W. OF IND. STATES     10293011
#
#              Area Pop. Density  Coastline  Net migration Infant mortality  \
# 0          647500          48,0       0,00         23,06           163,07
# 1           28748         124,6       1,26         -4,93            21,52
# 2         2381740          13,8       0,04         -0,39               31
# 3             199         290,4      58,29        -20,71             9,27
# 4             468         152,1       0,00           6,6             4,05
# 5         1246700           9,7       0,13             0           191,19
# 6   not available         132,1      59,80         10,76            21,03
# 7             NaN         156,0      34,54         -6,15            19,46
# 8   not available          14,4       0,18          0,61            15,18
# 9           29800          99,9       0,00         -6,47            23,28
# 10            193         372,5      35,49             0             5,89
# 11        7686850           2,6       0,34          3,98             4,69
# 12          83870          97,7       0,00             2             4,66
# 13          86600          91,9       0,00          -4,9            81,74
# 14          13940          21,8      25,41          -2,2            25,21
# 15            665        1050,5      24,21          1,05            17,27
# 16         144000        1023,4       0,40         -0,71             62,6
# 17            431         649,5      22,51         -0,31             12,5
# 18         207600          49,6       0,00          2,54            13,37
#
#      GDP  Literacy Phones Arable Crops  Other  Climate Birthrate Deathrate  \
# 0     700     36,0    3,2  12,13  0,22  87,65      1.0      46,6     20,34
# 1    4500     86,5   71,2  21,09  4,42  74,49      3.0     15,11      5,22
# 2    6000     70,0   78,1   3,22  0,25  96,53      1.0     17,14      4,61
# 3    8000     97,0  259,5     10    15     75      2.0     22,46      3,27
# 4   19000    100,0  497,2   2,22     0  97,78      3.0      8,71      6,25
# 5    1900     42,0    7,8   2,41  0,24  97,35      NaN     45,11      24,2
# 6    8600     95,0  460,0      0     0    100      2.0     14,17      5,34
# 7   11000     89,0  549,9  18,18  4,55  77,27      2.0     16,93      5,37
# 8   11200     97,1  220,4  12,31  0,48  87,21      3.0     16,73      7,55
# 9    3500     98,6  195,7  17,55   2,3  80,15      4.0     12,07      8,23
# 10  28000     97,0  516,1  10,53     0  89,47      2.0     11,03      6,68
# 11  29000    100,0  565,5   6,55  0,04  93,41      1.0     12,14      7,51
# 12  30000     98,0  452,2  16,91  0,86  82,23      3.0      8,74      9,76
# 13   3400     97,0  137,1  19,63  2,71  77,66      1.0     20,74      9,75
# 14  16700     95,6  460,6    0,8   0,4   98,8      2.0     17,57      9,05
# 15  16900     89,1  281,3   2,82  5,63  91,55      1.0      17,8      4,14
# 16   1900     43,1    7,3  62,11  3,07  34,82      2.0      29,8      8,27
# 17  15700     97,4  481,9  37,21  2,33  60,46      2.0     12,71      8,67
# 18   6100     99,6  319,1  29,55   0,6  69,85      4.0     11,16     14,02
#
#    Agriculture Industry Service
# 0         0,38     0,24    0,38
# 1        0,232    0,188   0,579
# 2        0,101      0,6   0,298
# 3          NaN      NaN     NaN
# 4          NaN      NaN     NaN
# 5        0,096    0,658   0,246
# 6         0,04     0,18    0,78
# 7        0,038     0,22   0,743
# 8        0,095    0,358   0,547
# 9        0,239    0,343   0,418
# 10       0,004    0,333   0,663
# 11       0,038    0,262     0,7
# 12       0,018    0,304   0,678
# 13       0,141    0,457   0,402
# 14        0,03     0,07     0,9
# 15       0,005    0,387   0,608
# 16       0,199    0,198   0,603
# 17        0,06     0,16    0,78
# 18       0,093    0,316   0,591

# %% [markdown]
# # na_values parameter in read_csv() function:-
# # The na_values parameter in the pandas.read_csv() function allows you to specify a list of values that should be treated as missing values (NaN) when reading in a CSV file.

# %%
pd.read_csv("C:\\Users\\User\\Downloads\\countries of the world.csv",na_values ='not available')
# Out:
#                Country                               Region  Population  \
# 0         Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1             Albania                             no values     3581655
# 2             Algeria                                   NaN    32930091
# 3      American Samoa                                   NaN       57794
# 4             Andorra   WESTERN EUROPE                            71201
# 5              Angola   SUB-SAHARAN AFRICA                     12127071
# 6            Anguilla               LATIN AMER. & CARIB           13477
# 7   Antigua & Barbuda               LATIN AMER. & CARIB           69108
# 8           Argentina               LATIN AMER. & CARIB        39921833
# 9             Armenia                  C.W. OF IND. STATES      2976372
# 10              Aruba               LATIN AMER. & CARIB           71891
# 11          Australia   OCEANIA                                20264082
# 12            Austria   WESTERN EUROPE                          8192880
# 13         Azerbaijan                  C.W. OF IND. STATES      7961619
# 14       Bahamas, The               LATIN AMER. & CARIB          303770
# 15            Bahrain   NEAR EAST                                698585
# 16         Bangladesh         ASIA (EX. NEAR EAST)            147365352
# 17           Barbados               LATIN AMER. & CARIB          279912
# 18            Belarus                  C.W. OF IND. STATES     10293011
#
#          Area Pop. Density  Coastline  Net migration Infant mortality   GDP   \
# 0    647500.0          48,0       0,00         23,06           163,07    700
# 1     28748.0         124,6       1,26         -4,93            21,52   4500
# 2   2381740.0          13,8       0,04         -0,39               31   6000
# 3       199.0         290,4      58,29        -20,71             9,27   8000
# 4       468.0         152,1       0,00           6,6             4,05  19000
# 5   1246700.0           9,7       0,13             0           191,19   1900
# 6         NaN         132,1      59,80         10,76            21,03   8600
# 7         NaN         156,0      34,54         -6,15            19,46  11000
# 8         NaN          14,4       0,18          0,61            15,18  11200
# 9     29800.0          99,9       0,00         -6,47            23,28   3500
# 10      193.0         372,5      35,49             0             5,89  28000
# 11  7686850.0           2,6       0,34          3,98             4,69  29000
# 12    83870.0          97,7       0,00             2             4,66  30000
# 13    86600.0          91,9       0,00          -4,9            81,74   3400
# 14    13940.0          21,8      25,41          -2,2            25,21  16700
# 15      665.0        1050,5      24,21          1,05            17,27  16900
# 16   144000.0        1023,4       0,40         -0,71             62,6   1900
# 17      431.0         649,5      22,51         -0,31             12,5  15700
# 18   207600.0          49,6       0,00          2,54            13,37   6100
#
#    Literacy Phones Arable Crops  Other  Climate Birthrate Deathrate  \
# 0      36,0    3,2  12,13  0,22  87,65      1.0      46,6     20,34
# 1      86,5   71,2  21,09  4,42  74,49      3.0     15,11      5,22
# 2      70,0   78,1   3,22  0,25  96,53      1.0     17,14      4,61
# 3      97,0  259,5     10    15     75      2.0     22,46      3,27
# 4     100,0  497,2   2,22     0  97,78      3.0      8,71      6,25
# 5      42,0    7,8   2,41  0,24  97,35      NaN     45,11      24,2
# 6      95,0  460,0      0     0    100      2.0     14,17      5,34
# 7      89,0  549,9  18,18  4,55  77,27      2.0     16,93      5,37
# 8      97,1  220,4  12,31  0,48  87,21      3.0     16,73      7,55
# 9      98,6  195,7  17,55   2,3  80,15      4.0     12,07      8,23
# 10     97,0  516,1  10,53     0  89,47      2.0     11,03      6,68
# 11    100,0  565,5   6,55  0,04  93,41      1.0     12,14      7,51
# 12     98,0  452,2  16,91  0,86  82,23      3.0      8,74      9,76
# 13     97,0  137,1  19,63  2,71  77,66      1.0     20,74      9,75
# 14     95,6  460,6    0,8   0,4   98,8      2.0     17,57      9,05
# 15     89,1  281,3   2,82  5,63  91,55      1.0      17,8      4,14
# 16     43,1    7,3  62,11  3,07  34,82      2.0      29,8      8,27
# 17     97,4  481,9  37,21  2,33  60,46      2.0     12,71      8,67
# 18     99,6  319,1  29,55   0,6  69,85      4.0     11,16     14,02
#
#    Agriculture Industry Service
# 0         0,38     0,24    0,38
# 1        0,232    0,188   0,579
# 2        0,101      0,6   0,298
# 3          NaN      NaN     NaN
# 4          NaN      NaN     NaN
# 5        0,096    0,658   0,246
# 6         0,04     0,18    0,78
# 7        0,038     0,22   0,743
# 8        0,095    0,358   0,547
# 9        0,239    0,343   0,418
# 10       0,004    0,333   0,663
# 11       0,038    0,262     0,7
# 12       0,018    0,304   0,678
# 13       0,141    0,457   0,402
# 14        0,03     0,07     0,9
# 15       0,005    0,387   0,608
# 16       0,199    0,198   0,603
# 17        0,06     0,16    0,78
# 18       0,093    0,316   0,591

# %%
pd.read_csv("C:\\Users\\User\\Downloads\\countries of the world.csv",na_values = ['not available','no values'])
# Out:
#                Country                               Region  Population  \
# 0         Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1             Albania                                   NaN     3581655
# 2             Algeria                                   NaN    32930091
# 3      American Samoa                                   NaN       57794
# 4             Andorra   WESTERN EUROPE                            71201
# 5              Angola   SUB-SAHARAN AFRICA                     12127071
# 6            Anguilla               LATIN AMER. & CARIB           13477
# 7   Antigua & Barbuda               LATIN AMER. & CARIB           69108
# 8           Argentina               LATIN AMER. & CARIB        39921833
# 9             Armenia                  C.W. OF IND. STATES      2976372
# 10              Aruba               LATIN AMER. & CARIB           71891
# 11          Australia   OCEANIA                                20264082
# 12            Austria   WESTERN EUROPE                          8192880
# 13         Azerbaijan                  C.W. OF IND. STATES      7961619
# 14       Bahamas, The               LATIN AMER. & CARIB          303770
# 15            Bahrain   NEAR EAST                                698585
# 16         Bangladesh         ASIA (EX. NEAR EAST)            147365352
# 17           Barbados               LATIN AMER. & CARIB          279912
# 18            Belarus                  C.W. OF IND. STATES     10293011
#
#          Area Pop. Density  Coastline  Net migration Infant mortality   GDP   \
# 0    647500.0          48,0       0,00         23,06           163,07    700
# 1     28748.0         124,6       1,26         -4,93            21,52   4500
# 2   2381740.0          13,8       0,04         -0,39               31   6000
# 3       199.0         290,4      58,29        -20,71             9,27   8000
# 4       468.0         152,1       0,00           6,6             4,05  19000
# 5   1246700.0           9,7       0,13             0           191,19   1900
# 6         NaN         132,1      59,80         10,76            21,03   8600
# 7         NaN         156,0      34,54         -6,15            19,46  11000
# 8         NaN          14,4       0,18          0,61            15,18  11200
# 9     29800.0          99,9       0,00         -6,47            23,28   3500
# 10      193.0         372,5      35,49             0             5,89  28000
# 11  7686850.0           2,6       0,34          3,98             4,69  29000
# 12    83870.0          97,7       0,00             2             4,66  30000
# 13    86600.0          91,9       0,00          -4,9            81,74   3400
# 14    13940.0          21,8      25,41          -2,2            25,21  16700
# 15      665.0        1050,5      24,21          1,05            17,27  16900
# 16   144000.0        1023,4       0,40         -0,71             62,6   1900
# 17      431.0         649,5      22,51         -0,31             12,5  15700
# 18   207600.0          49,6       0,00          2,54            13,37   6100
#
#    Literacy Phones Arable Crops  Other  Climate Birthrate Deathrate  \
# 0      36,0    3,2  12,13  0,22  87,65      1.0      46,6     20,34
# 1      86,5   71,2  21,09  4,42  74,49      3.0     15,11      5,22
# 2      70,0   78,1   3,22  0,25  96,53      1.0     17,14      4,61
# 3      97,0  259,5     10    15     75      2.0     22,46      3,27
# 4     100,0  497,2   2,22     0  97,78      3.0      8,71      6,25
# 5      42,0    7,8   2,41  0,24  97,35      NaN     45,11      24,2
# 6      95,0  460,0      0     0    100      2.0     14,17      5,34
# 7      89,0  549,9  18,18  4,55  77,27      2.0     16,93      5,37
# 8      97,1  220,4  12,31  0,48  87,21      3.0     16,73      7,55
# 9      98,6  195,7  17,55   2,3  80,15      4.0     12,07      8,23
# 10     97,0  516,1  10,53     0  89,47      2.0     11,03      6,68
# 11    100,0  565,5   6,55  0,04  93,41      1.0     12,14      7,51
# 12     98,0  452,2  16,91  0,86  82,23      3.0      8,74      9,76
# 13     97,0  137,1  19,63  2,71  77,66      1.0     20,74      9,75
# 14     95,6  460,6    0,8   0,4   98,8      2.0     17,57      9,05
# 15     89,1  281,3   2,82  5,63  91,55      1.0      17,8      4,14
# 16     43,1    7,3  62,11  3,07  34,82      2.0      29,8      8,27
# 17     97,4  481,9  37,21  2,33  60,46      2.0     12,71      8,67
# 18     99,6  319,1  29,55   0,6  69,85      4.0     11,16     14,02
#
#    Agriculture Industry Service
# 0         0,38     0,24    0,38
# 1        0,232    0,188   0,579
# 2        0,101      0,6   0,298
# 3          NaN      NaN     NaN
# 4          NaN      NaN     NaN
# 5        0,096    0,658   0,246
# 6         0,04     0,18    0,78
# 7        0,038     0,22   0,743
# 8        0,095    0,358   0,547
# 9        0,239    0,343   0,418
# 10       0,004    0,333   0,663
# 11       0,038    0,262     0,7
# 12       0,018    0,304   0,678
# 13       0,141    0,457   0,402
# 14        0,03     0,07     0,9
# 15       0,005    0,387   0,608
# 16       0,199    0,198   0,603
# 17        0,06     0,16    0,78
# 18       0,093    0,316   0,591

# %%
pd.read_csv("C:\\Users\\User\\Downloads\\countries of the world.csv")
# Out:
#                Country                               Region  Population  \
# 0         Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1             Albania                             no values     3581655
# 2             Algeria                                   NaN    32930091
# 3      American Samoa                         not available       57794
# 4             Andorra   WESTERN EUROPE                            71201
# 5              Angola   SUB-SAHARAN AFRICA                     12127071
# 6            Anguilla               LATIN AMER. & CARIB           13477
# 7   Antigua & Barbuda               LATIN AMER. & CARIB           69108
# 8           Argentina               LATIN AMER. & CARIB        39921833
# 9             Armenia                  C.W. OF IND. STATES      2976372
# 10              Aruba               LATIN AMER. & CARIB           71891
# 11          Australia   OCEANIA                                20264082
# 12            Austria   WESTERN EUROPE                          8192880
# 13         Azerbaijan                  C.W. OF IND. STATES      7961619
# 14       Bahamas, The               LATIN AMER. & CARIB          303770
# 15            Bahrain   NEAR EAST                                698585
# 16         Bangladesh         ASIA (EX. NEAR EAST)            147365352
# 17           Barbados               LATIN AMER. & CARIB          279912
# 18            Belarus                  C.W. OF IND. STATES     10293011
#
#              Area Pop. Density  Coastline  Net migration Infant mortality  \
# 0          647500          48,0       0,00         23,06           163,07
# 1           28748         124,6       1,26         -4,93            21,52
# 2         2381740          13,8       0,04         -0,39               31
# 3             199         290,4      58,29        -20,71             9,27
# 4             468         152,1       0,00           6,6             4,05
# 5         1246700           9,7       0,13             0           191,19
# 6   not available         132,1      59,80         10,76            21,03
# 7             NaN         156,0      34,54         -6,15            19,46
# 8   not available          14,4       0,18          0,61            15,18
# 9           29800          99,9       0,00         -6,47            23,28
# 10            193         372,5      35,49             0             5,89
# 11        7686850           2,6       0,34          3,98             4,69
# 12          83870          97,7       0,00             2             4,66
# 13          86600          91,9       0,00          -4,9            81,74
# 14          13940          21,8      25,41          -2,2            25,21
# 15            665        1050,5      24,21          1,05            17,27
# 16         144000        1023,4       0,40         -0,71             62,6
# 17            431         649,5      22,51         -0,31             12,5
# 18         207600          49,6       0,00          2,54            13,37
#
#      GDP  Literacy Phones Arable Crops  Other  Climate Birthrate Deathrate  \
# 0     700     36,0    3,2  12,13  0,22  87,65      1.0      46,6     20,34
# 1    4500     86,5   71,2  21,09  4,42  74,49      3.0     15,11      5,22
# 2    6000     70,0   78,1   3,22  0,25  96,53      1.0     17,14      4,61
# 3    8000     97,0  259,5     10    15     75      2.0     22,46      3,27
# 4   19000    100,0  497,2   2,22     0  97,78      3.0      8,71      6,25
# 5    1900     42,0    7,8   2,41  0,24  97,35      NaN     45,11      24,2
# 6    8600     95,0  460,0      0     0    100      2.0     14,17      5,34
# 7   11000     89,0  549,9  18,18  4,55  77,27      2.0     16,93      5,37
# 8   11200     97,1  220,4  12,31  0,48  87,21      3.0     16,73      7,55
# 9    3500     98,6  195,7  17,55   2,3  80,15      4.0     12,07      8,23
# 10  28000     97,0  516,1  10,53     0  89,47      2.0     11,03      6,68
# 11  29000    100,0  565,5   6,55  0,04  93,41      1.0     12,14      7,51
# 12  30000     98,0  452,2  16,91  0,86  82,23      3.0      8,74      9,76
# 13   3400     97,0  137,1  19,63  2,71  77,66      1.0     20,74      9,75
# 14  16700     95,6  460,6    0,8   0,4   98,8      2.0     17,57      9,05
# 15  16900     89,1  281,3   2,82  5,63  91,55      1.0      17,8      4,14
# 16   1900     43,1    7,3  62,11  3,07  34,82      2.0      29,8      8,27
# 17  15700     97,4  481,9  37,21  2,33  60,46      2.0     12,71      8,67
# 18   6100     99,6  319,1  29,55   0,6  69,85      4.0     11,16     14,02
#
#    Agriculture Industry Service
# 0         0,38     0,24    0,38
# 1        0,232    0,188   0,579
# 2        0,101      0,6   0,298
# 3          NaN      NaN     NaN
# 4          NaN      NaN     NaN
# 5        0,096    0,658   0,246
# 6         0,04     0,18    0,78
# 7        0,038     0,22   0,743
# 8        0,095    0,358   0,547
# 9        0,239    0,343   0,418
# 10       0,004    0,333   0,663
# 11       0,038    0,262     0,7
# 12       0,018    0,304   0,678
# 13       0,141    0,457   0,402
# 14        0,03     0,07     0,9
# 15       0,005    0,387   0,608
# 16       0,199    0,198   0,603
# 17        0,06     0,16    0,78
# 18       0,093    0,316   0,591

# %%
pd.read_csv("C:\\Users\\User\\Downloads\\countries of the world.csv",na_values={'Region':'no values','Area':'not available'})
# Out:
#                Country                               Region  Population  \
# 0         Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1             Albania                                   NaN     3581655
# 2             Algeria                                   NaN    32930091
# 3      American Samoa                         not available       57794
# 4             Andorra   WESTERN EUROPE                            71201
# 5              Angola   SUB-SAHARAN AFRICA                     12127071
# 6            Anguilla               LATIN AMER. & CARIB           13477
# 7   Antigua & Barbuda               LATIN AMER. & CARIB           69108
# 8           Argentina               LATIN AMER. & CARIB        39921833
# 9             Armenia                  C.W. OF IND. STATES      2976372
# 10              Aruba               LATIN AMER. & CARIB           71891
# 11          Australia   OCEANIA                                20264082
# 12            Austria   WESTERN EUROPE                          8192880
# 13         Azerbaijan                  C.W. OF IND. STATES      7961619
# 14       Bahamas, The               LATIN AMER. & CARIB          303770
# 15            Bahrain   NEAR EAST                                698585
# 16         Bangladesh         ASIA (EX. NEAR EAST)            147365352
# 17           Barbados               LATIN AMER. & CARIB          279912
# 18            Belarus                  C.W. OF IND. STATES     10293011
#
#          Area Pop. Density  Coastline  Net migration Infant mortality   GDP   \
# 0    647500.0          48,0       0,00         23,06           163,07    700
# 1     28748.0         124,6       1,26         -4,93            21,52   4500
# 2   2381740.0          13,8       0,04         -0,39               31   6000
# 3       199.0         290,4      58,29        -20,71             9,27   8000
# 4       468.0         152,1       0,00           6,6             4,05  19000
# 5   1246700.0           9,7       0,13             0           191,19   1900
# 6         NaN         132,1      59,80         10,76            21,03   8600
# 7         NaN         156,0      34,54         -6,15            19,46  11000
# 8         NaN          14,4       0,18          0,61            15,18  11200
# 9     29800.0          99,9       0,00         -6,47            23,28   3500
# 10      193.0         372,5      35,49             0             5,89  28000
# 11  7686850.0           2,6       0,34          3,98             4,69  29000
# 12    83870.0          97,7       0,00             2             4,66  30000
# 13    86600.0          91,9       0,00          -4,9            81,74   3400
# 14    13940.0          21,8      25,41          -2,2            25,21  16700
# 15      665.0        1050,5      24,21          1,05            17,27  16900
# 16   144000.0        1023,4       0,40         -0,71             62,6   1900
# 17      431.0         649,5      22,51         -0,31             12,5  15700
# 18   207600.0          49,6       0,00          2,54            13,37   6100
#
#    Literacy Phones Arable Crops  Other  Climate Birthrate Deathrate  \
# 0      36,0    3,2  12,13  0,22  87,65      1.0      46,6     20,34
# 1      86,5   71,2  21,09  4,42  74,49      3.0     15,11      5,22
# 2      70,0   78,1   3,22  0,25  96,53      1.0     17,14      4,61
# 3      97,0  259,5     10    15     75      2.0     22,46      3,27
# 4     100,0  497,2   2,22     0  97,78      3.0      8,71      6,25
# 5      42,0    7,8   2,41  0,24  97,35      NaN     45,11      24,2
# 6      95,0  460,0      0     0    100      2.0     14,17      5,34
# 7      89,0  549,9  18,18  4,55  77,27      2.0     16,93      5,37
# 8      97,1  220,4  12,31  0,48  87,21      3.0     16,73      7,55
# 9      98,6  195,7  17,55   2,3  80,15      4.0     12,07      8,23
# 10     97,0  516,1  10,53     0  89,47      2.0     11,03      6,68
# 11    100,0  565,5   6,55  0,04  93,41      1.0     12,14      7,51
# 12     98,0  452,2  16,91  0,86  82,23      3.0      8,74      9,76
# 13     97,0  137,1  19,63  2,71  77,66      1.0     20,74      9,75
# 14     95,6  460,6    0,8   0,4   98,8      2.0     17,57      9,05
# 15     89,1  281,3   2,82  5,63  91,55      1.0      17,8      4,14
# 16     43,1    7,3  62,11  3,07  34,82      2.0      29,8      8,27
# 17     97,4  481,9  37,21  2,33  60,46      2.0     12,71      8,67
# 18     99,6  319,1  29,55   0,6  69,85      4.0     11,16     14,02
#
#    Agriculture Industry Service
# 0         0,38     0,24    0,38
# 1        0,232    0,188   0,579
# 2        0,101      0,6   0,298
# 3          NaN      NaN     NaN
# 4          NaN      NaN     NaN
# 5        0,096    0,658   0,246
# 6         0,04     0,18    0,78
# 7        0,038     0,22   0,743
# 8        0,095    0,358   0,547
# 9        0,239    0,343   0,418
# 10       0,004    0,333   0,663
# 11       0,038    0,262     0,7
# 12       0,018    0,304   0,678
# 13       0,141    0,457   0,402
# 14        0,03     0,07     0,9
# 15       0,005    0,387   0,608
# 16       0,199    0,198   0,603
# 17        0,06     0,16    0,78
# 18       0,093    0,316   0,591

# %% [markdown]
# # keep_default_na parameter in read_csv() function:-
# # The keep_default_na parameter in the pandas.read_csv() function controls how missing values are handled during the reading process.

# %%
pd.read_csv("C:\\Users\\User\\Downloads\\countries of the world.csv",keep_default_na = False)
# Out:
#                Country                               Region  Population  \
# 0         Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1             Albania                             no values     3581655
# 2             Algeria                                  #N/A    32930091
# 3      American Samoa                         not available       57794
# 4             Andorra   WESTERN EUROPE                            71201
# 5              Angola   SUB-SAHARAN AFRICA                     12127071
# 6            Anguilla               LATIN AMER. & CARIB           13477
# 7   Antigua & Barbuda               LATIN AMER. & CARIB           69108
# 8           Argentina               LATIN AMER. & CARIB        39921833
# 9             Armenia                  C.W. OF IND. STATES      2976372
# 10              Aruba               LATIN AMER. & CARIB           71891
# 11          Australia   OCEANIA                                20264082
# 12            Austria   WESTERN EUROPE                          8192880
# 13         Azerbaijan                  C.W. OF IND. STATES      7961619
# 14       Bahamas, The               LATIN AMER. & CARIB          303770
# 15            Bahrain   NEAR EAST                                698585
# 16         Bangladesh         ASIA (EX. NEAR EAST)            147365352
# 17           Barbados               LATIN AMER. & CARIB          279912
# 18            Belarus                  C.W. OF IND. STATES     10293011
#
#              Area Pop. Density  Coastline  Net migration Infant mortality  \
# 0          647500          48,0       0,00         23,06           163,07
# 1           28748         124,6       1,26         -4,93            21,52
# 2         2381740          13,8       0,04         -0,39               31
# 3             199         290,4      58,29        -20,71             9,27
# 4             468         152,1       0,00           6,6             4,05
# 5         1246700           9,7       0,13             0           191,19
# 6   not available         132,1      59,80         10,76            21,03
# 7            null         156,0      34,54         -6,15            19,46
# 8   not available          14,4       0,18          0,61            15,18
# 9           29800          99,9       0,00         -6,47            23,28
# 10            193         372,5      35,49             0             5,89
# 11        7686850           2,6       0,34          3,98             4,69
# 12          83870          97,7       0,00             2             4,66
# 13          86600          91,9       0,00          -4,9            81,74
# 14          13940          21,8      25,41          -2,2            25,21
# 15            665        1050,5      24,21          1,05            17,27
# 16         144000        1023,4       0,40         -0,71             62,6
# 17            431         649,5      22,51         -0,31             12,5
# 18         207600          49,6       0,00          2,54            13,37
#
#      GDP  Literacy Phones Arable Crops  Other Climate Birthrate Deathrate  \
# 0     700     36,0    3,2  12,13  0,22  87,65       1      46,6     20,34
# 1    4500     86,5   71,2  21,09  4,42  74,49       3     15,11      5,22
# 2    6000     70,0   78,1   3,22  0,25  96,53       1     17,14      4,61
# 3    8000     97,0  259,5     10    15     75       2     22,46      3,27
# 4   19000    100,0  497,2   2,22     0  97,78       3      8,71      6,25
# 5    1900     42,0    7,8   2,41  0,24  97,35             45,11      24,2
# 6    8600     95,0  460,0      0     0    100       2     14,17      5,34
# 7   11000     89,0  549,9  18,18  4,55  77,27       2     16,93      5,37
# 8   11200     97,1  220,4  12,31  0,48  87,21       3     16,73      7,55
# 9    3500     98,6  195,7  17,55   2,3  80,15       4     12,07      8,23
# 10  28000     97,0  516,1  10,53     0  89,47       2     11,03      6,68
# 11  29000    100,0  565,5   6,55  0,04  93,41       1     12,14      7,51
# 12  30000     98,0  452,2  16,91  0,86  82,23       3      8,74      9,76
# 13   3400     97,0  137,1  19,63  2,71  77,66       1     20,74      9,75
# 14  16700     95,6  460,6    0,8   0,4   98,8       2     17,57      9,05
# 15  16900     89,1  281,3   2,82  5,63  91,55       1      17,8      4,14
# 16   1900     43,1    7,3  62,11  3,07  34,82       2      29,8      8,27
# 17  15700     97,4  481,9  37,21  2,33  60,46       2     12,71      8,67
# 18   6100     99,6  319,1  29,55   0,6  69,85       4     11,16     14,02
#
#    Agriculture Industry Service
# 0         0,38     0,24    0,38
# 1        0,232    0,188   0,579
# 2        0,101      0,6   0,298
# 3
# 4
# 5        0,096    0,658   0,246
# 6         0,04     0,18    0,78
# 7        0,038     0,22   0,743
# 8        0,095    0,358   0,547
# 9        0,239    0,343   0,418
# 10       0,004    0,333   0,663
# 11       0,038    0,262     0,7
# 12       0,018    0,304   0,678
# 13       0,141    0,457   0,402
# 14        0,03     0,07     0,9
# 15       0,005    0,387   0,608
# 16       0,199    0,198   0,603
# 17        0,06     0,16    0,78
# 18       0,093    0,316   0,591

# %%
pd.read_csv("C:\\Users\\User\\Downloads\\countries of the world.csv",keep_default_na = True)
# Out:
#                Country                               Region  Population  \
# 0         Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1             Albania                             no values     3581655
# 2             Algeria                                   NaN    32930091
# 3      American Samoa                         not available       57794
# 4             Andorra   WESTERN EUROPE                            71201
# 5              Angola   SUB-SAHARAN AFRICA                     12127071
# 6            Anguilla               LATIN AMER. & CARIB           13477
# 7   Antigua & Barbuda               LATIN AMER. & CARIB           69108
# 8           Argentina               LATIN AMER. & CARIB        39921833
# 9             Armenia                  C.W. OF IND. STATES      2976372
# 10              Aruba               LATIN AMER. & CARIB           71891
# 11          Australia   OCEANIA                                20264082
# 12            Austria   WESTERN EUROPE                          8192880
# 13         Azerbaijan                  C.W. OF IND. STATES      7961619
# 14       Bahamas, The               LATIN AMER. & CARIB          303770
# 15            Bahrain   NEAR EAST                                698585
# 16         Bangladesh         ASIA (EX. NEAR EAST)            147365352
# 17           Barbados               LATIN AMER. & CARIB          279912
# 18            Belarus                  C.W. OF IND. STATES     10293011
#
#              Area Pop. Density  Coastline  Net migration Infant mortality  \
# 0          647500          48,0       0,00         23,06           163,07
# 1           28748         124,6       1,26         -4,93            21,52
# 2         2381740          13,8       0,04         -0,39               31
# 3             199         290,4      58,29        -20,71             9,27
# 4             468         152,1       0,00           6,6             4,05
# 5         1246700           9,7       0,13             0           191,19
# 6   not available         132,1      59,80         10,76            21,03
# 7             NaN         156,0      34,54         -6,15            19,46
# 8   not available          14,4       0,18          0,61            15,18
# 9           29800          99,9       0,00         -6,47            23,28
# 10            193         372,5      35,49             0             5,89
# 11        7686850           2,6       0,34          3,98             4,69
# 12          83870          97,7       0,00             2             4,66
# 13          86600          91,9       0,00          -4,9            81,74
# 14          13940          21,8      25,41          -2,2            25,21
# 15            665        1050,5      24,21          1,05            17,27
# 16         144000        1023,4       0,40         -0,71             62,6
# 17            431         649,5      22,51         -0,31             12,5
# 18         207600          49,6       0,00          2,54            13,37
#
#      GDP  Literacy Phones Arable Crops  Other  Climate Birthrate Deathrate  \
# 0     700     36,0    3,2  12,13  0,22  87,65      1.0      46,6     20,34
# 1    4500     86,5   71,2  21,09  4,42  74,49      3.0     15,11      5,22
# 2    6000     70,0   78,1   3,22  0,25  96,53      1.0     17,14      4,61
# 3    8000     97,0  259,5     10    15     75      2.0     22,46      3,27
# 4   19000    100,0  497,2   2,22     0  97,78      3.0      8,71      6,25
# 5    1900     42,0    7,8   2,41  0,24  97,35      NaN     45,11      24,2
# 6    8600     95,0  460,0      0     0    100      2.0     14,17      5,34
# 7   11000     89,0  549,9  18,18  4,55  77,27      2.0     16,93      5,37
# 8   11200     97,1  220,4  12,31  0,48  87,21      3.0     16,73      7,55
# 9    3500     98,6  195,7  17,55   2,3  80,15      4.0     12,07      8,23
# 10  28000     97,0  516,1  10,53     0  89,47      2.0     11,03      6,68
# 11  29000    100,0  565,5   6,55  0,04  93,41      1.0     12,14      7,51
# 12  30000     98,0  452,2  16,91  0,86  82,23      3.0      8,74      9,76
# 13   3400     97,0  137,1  19,63  2,71  77,66      1.0     20,74      9,75
# 14  16700     95,6  460,6    0,8   0,4   98,8      2.0     17,57      9,05
# 15  16900     89,1  281,3   2,82  5,63  91,55      1.0      17,8      4,14
# 16   1900     43,1    7,3  62,11  3,07  34,82      2.0      29,8      8,27
# 17  15700     97,4  481,9  37,21  2,33  60,46      2.0     12,71      8,67
# 18   6100     99,6  319,1  29,55   0,6  69,85      4.0     11,16     14,02
#
#    Agriculture Industry Service
# 0         0,38     0,24    0,38
# 1        0,232    0,188   0,579
# 2        0,101      0,6   0,298
# 3          NaN      NaN     NaN
# 4          NaN      NaN     NaN
# 5        0,096    0,658   0,246
# 6         0,04     0,18    0,78
# 7        0,038     0,22   0,743
# 8        0,095    0,358   0,547
# 9        0,239    0,343   0,418
# 10       0,004    0,333   0,663
# 11       0,038    0,262     0,7
# 12       0,018    0,304   0,678
# 13       0,141    0,457   0,402
# 14        0,03     0,07     0,9
# 15       0,005    0,387   0,608
# 16       0,199    0,198   0,603
# 17        0,06     0,16    0,78
# 18       0,093    0,316   0,591

# %% [markdown]
# # na_filter parameter in read_csv() function:-
# # The na_filter parameter in the pandas.read_csv() function controls whether pandas should attempt to convert empty cells to NaN values.

# %%
pd.read_csv("C:\\Users\\User\\Downloads\\countries of the world 1.csv",na_filter = False)
# Out:
#                Country                               Region  Population  \
# 0         Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1             Albania                        WESTERN EUROPE     3581655
# 2             Algeria                        WESTERN EUROPE    32930091
# 3      American Samoa                        WESTERN EUROPE       57794
# 4             Andorra   WESTERN EUROPE                            71201
# 5              Angola   SUB-SAHARAN AFRICA                     12127071
# 6            Anguilla               LATIN AMER. & CARIB           13477
# 7   Antigua & Barbuda               LATIN AMER. & CARIB           69108
# 8           Argentina               LATIN AMER. & CARIB        39921833
# 9             Armenia                  C.W. OF IND. STATES      2976372
# 10              Aruba               LATIN AMER. & CARIB           71891
# 11          Australia   OCEANIA                                20264082
# 12            Austria   WESTERN EUROPE                          8192880
# 13         Azerbaijan                  C.W. OF IND. STATES      7961619
# 14       Bahamas, The               LATIN AMER. & CARIB          303770
# 15            Bahrain   NEAR EAST                                698585
# 16         Bangladesh         ASIA (EX. NEAR EAST)            147365352
# 17           Barbados               LATIN AMER. & CARIB          279912
# 18            Belarus                  C.W. OF IND. STATES     10293011
#
#        Area Pop. Density  Coastline  Net migration Infant mortality   GDP   \
# 0    647500          48,0       0,00         23,06           163,07    700
# 1     28748         124,6       1,26         -4,93            21,52   4500
# 2   2381740          13,8       0,04         -0,39               31   6000
# 3       199         290,4      58,29        -20,71             9,27   8000
# 4       468         152,1       0,00           6,6             4,05  19000
# 5   1246700           9,7       0,13             0           191,19   1900
# 6   1246700         132,1      59,80         10,76            21,03   8600
# 7   1246700         156,0      34,54         -6,15            19,46  11000
# 8   1246700          14,4       0,18          0,61            15,18  11200
# 9     29800          99,9       0,00         -6,47            23,28   3500
# 10      193         372,5      35,49             0             5,89  28000
# 11  7686850           2,6       0,34          3,98             4,69  29000
# 12    83870          97,7       0,00             2             4,66  30000
# 13    86600          91,9       0,00          -4,9            81,74   3400
# 14    13940          21,8      25,41          -2,2            25,21  16700
# 15      665        1050,5      24,21          1,05            17,27  16900
# 16   144000        1023,4       0,40         -0,71             62,6   1900
# 17      431         649,5      22,51         -0,31             12,5  15700
# 18   207600          49,6       0,00          2,54            13,37   6100
#
#    Literacy Phones Arable Crops  Other Climate Birthrate Deathrate  \
# 0      36,0    3,2  12,13  0,22  87,65       1      46,6     20,34
# 1      86,5   71,2  21,09  4,42  74,49       3     15,11      5,22
# 2      70,0   78,1   3,22  0,25  96,53       1     17,14      4,61
# 3      97,0  259,5     10    15     75       2     22,46      3,27
# 4     100,0  497,2   2,22     0  97,78       3      8,71      6,25
# 5      42,0    7,8   2,41  0,24  97,35             45,11      24,2
# 6      95,0  460,0      0     0    100       2     14,17      5,34
# 7      89,0  549,9  18,18  4,55  77,27       2     16,93      5,37
# 8      97,1  220,4  12,31  0,48  87,21       3     16,73      7,55
# 9      98,6  195,7  17,55   2,3  80,15       4     12,07      8,23
# 10     97,0  516,1  10,53     0  89,47       2     11,03      6,68
# 11    100,0  565,5   6,55  0,04  93,41       1     12,14      7,51
# 12     98,0  452,2  16,91  0,86  82,23       3      8,74      9,76
# 13     97,0  137,1  19,63  2,71  77,66       1     20,74      9,75
# 14     95,6  460,6    0,8   0,4   98,8       2     17,57      9,05
# 15     89,1  281,3   2,82  5,63  91,55       1      17,8      4,14
# 16     43,1    7,3  62,11  3,07  34,82       2      29,8      8,27
# 17     97,4  481,9  37,21  2,33  60,46       2     12,71      8,67
# 18     99,6  319,1  29,55   0,6  69,85       4     11,16     14,02
#
#    Agriculture Industry Service
# 0         0,38     0,24    0,38
# 1        0,232    0,188   0,579
# 2        0,101      0,6   0,298
# 3
# 4
# 5        0,096    0,658   0,246
# 6         0,04     0,18    0,78
# 7        0,038     0,22   0,743
# 8        0,095    0,358   0,547
# 9        0,239    0,343   0,418
# 10       0,004    0,333   0,663
# 11       0,038    0,262     0,7
# 12       0,018    0,304   0,678
# 13       0,141    0,457   0,402
# 14        0,03     0,07     0,9
# 15       0,005    0,387   0,608
# 16       0,199    0,198   0,603
# 17        0,06     0,16    0,78
# 18       0,093    0,316   0,591

# %%
pd.read_csv("C:\\Users\\User\\Downloads\\countries of the world 1.csv",na_filter = True)
# Out:
#                Country                               Region  Population  \
# 0         Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1             Albania                        WESTERN EUROPE     3581655
# 2             Algeria                        WESTERN EUROPE    32930091
# 3      American Samoa                        WESTERN EUROPE       57794
# 4             Andorra   WESTERN EUROPE                            71201
# 5              Angola   SUB-SAHARAN AFRICA                     12127071
# 6            Anguilla               LATIN AMER. & CARIB           13477
# 7   Antigua & Barbuda               LATIN AMER. & CARIB           69108
# 8           Argentina               LATIN AMER. & CARIB        39921833
# 9             Armenia                  C.W. OF IND. STATES      2976372
# 10              Aruba               LATIN AMER. & CARIB           71891
# 11          Australia   OCEANIA                                20264082
# 12            Austria   WESTERN EUROPE                          8192880
# 13         Azerbaijan                  C.W. OF IND. STATES      7961619
# 14       Bahamas, The               LATIN AMER. & CARIB          303770
# 15            Bahrain   NEAR EAST                                698585
# 16         Bangladesh         ASIA (EX. NEAR EAST)            147365352
# 17           Barbados               LATIN AMER. & CARIB          279912
# 18            Belarus                  C.W. OF IND. STATES     10293011
#
#        Area Pop. Density  Coastline  Net migration Infant mortality   GDP   \
# 0    647500          48,0       0,00         23,06           163,07    700
# 1     28748         124,6       1,26         -4,93            21,52   4500
# 2   2381740          13,8       0,04         -0,39               31   6000
# 3       199         290,4      58,29        -20,71             9,27   8000
# 4       468         152,1       0,00           6,6             4,05  19000
# 5   1246700           9,7       0,13             0           191,19   1900
# 6   1246700         132,1      59,80         10,76            21,03   8600
# 7   1246700         156,0      34,54         -6,15            19,46  11000
# 8   1246700          14,4       0,18          0,61            15,18  11200
# 9     29800          99,9       0,00         -6,47            23,28   3500
# 10      193         372,5      35,49             0             5,89  28000
# 11  7686850           2,6       0,34          3,98             4,69  29000
# 12    83870          97,7       0,00             2             4,66  30000
# 13    86600          91,9       0,00          -4,9            81,74   3400
# 14    13940          21,8      25,41          -2,2            25,21  16700
# 15      665        1050,5      24,21          1,05            17,27  16900
# 16   144000        1023,4       0,40         -0,71             62,6   1900
# 17      431         649,5      22,51         -0,31             12,5  15700
# 18   207600          49,6       0,00          2,54            13,37   6100
#
#    Literacy Phones Arable Crops  Other  Climate Birthrate Deathrate  \
# 0      36,0    3,2  12,13  0,22  87,65      1.0      46,6     20,34
# 1      86,5   71,2  21,09  4,42  74,49      3.0     15,11      5,22
# 2      70,0   78,1   3,22  0,25  96,53      1.0     17,14      4,61
# 3      97,0  259,5     10    15     75      2.0     22,46      3,27
# 4     100,0  497,2   2,22     0  97,78      3.0      8,71      6,25
# 5      42,0    7,8   2,41  0,24  97,35      NaN     45,11      24,2
# 6      95,0  460,0      0     0    100      2.0     14,17      5,34
# 7      89,0  549,9  18,18  4,55  77,27      2.0     16,93      5,37
# 8      97,1  220,4  12,31  0,48  87,21      3.0     16,73      7,55
# 9      98,6  195,7  17,55   2,3  80,15      4.0     12,07      8,23
# 10     97,0  516,1  10,53     0  89,47      2.0     11,03      6,68
# 11    100,0  565,5   6,55  0,04  93,41      1.0     12,14      7,51
# 12     98,0  452,2  16,91  0,86  82,23      3.0      8,74      9,76
# 13     97,0  137,1  19,63  2,71  77,66      1.0     20,74      9,75
# 14     95,6  460,6    0,8   0,4   98,8      2.0     17,57      9,05
# 15     89,1  281,3   2,82  5,63  91,55      1.0      17,8      4,14
# 16     43,1    7,3  62,11  3,07  34,82      2.0      29,8      8,27
# 17     97,4  481,9  37,21  2,33  60,46      2.0     12,71      8,67
# 18     99,6  319,1  29,55   0,6  69,85      4.0     11,16     14,02
#
#    Agriculture Industry Service
# 0         0,38     0,24    0,38
# 1        0,232    0,188   0,579
# 2        0,101      0,6   0,298
# 3          NaN      NaN     NaN
# 4          NaN      NaN     NaN
# 5        0,096    0,658   0,246
# 6         0,04     0,18    0,78
# 7        0,038     0,22   0,743
# 8        0,095    0,358   0,547
# 9        0,239    0,343   0,418
# 10       0,004    0,333   0,663
# 11       0,038    0,262     0,7
# 12       0,018    0,304   0,678
# 13       0,141    0,457   0,402
# 14        0,03     0,07     0,9
# 15       0,005    0,387   0,608
# 16       0,199    0,198   0,603
# 17        0,06     0,16    0,78
# 18       0,093    0,316   0,591

# %%
pd.read_csv("C:\\Users\\User\\Downloads\\countries of the world 2.csv")
# Out:
#                Country                               Region  Population  \
# 0         Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1             Albania                                   NaN     3581655
# 2             Algeria                                   NaN    32930091
# 3      American Samoa                                   NaN       57794
# 4             Andorra                                   NaN       71201
# 5              Angola   SUB-SAHARAN AFRICA                     12127071
# 6            Anguilla               LATIN AMER. & CARIB           13477
# 7   Antigua & Barbuda               LATIN AMER. & CARIB           69108
# 8           Argentina               LATIN AMER. & CARIB        39921833
# 9             Armenia                  C.W. OF IND. STATES      2976372
# 10              Aruba               LATIN AMER. & CARIB           71891
# 11          Australia   OCEANIA                                20264082
# 12            Austria   WESTERN EUROPE                          8192880
# 13         Azerbaijan                  C.W. OF IND. STATES      7961619
# 14       Bahamas, The               LATIN AMER. & CARIB          303770
# 15            Bahrain   NEAR EAST                                698585
# 16         Bangladesh         ASIA (EX. NEAR EAST)            147365352
# 17           Barbados               LATIN AMER. & CARIB          279912
# 18            Belarus                  C.W. OF IND. STATES     10293011
#
#          Area Pop. Density  Coastline  Net migration Infant mortality   GDP   \
# 0    647500.0          48,0       0,00         23,06           163,07    700
# 1     28748.0         124,6       1,26         -4,93            21,52   4500
# 2   2381740.0          13,8       0,04         -0,39               31   6000
# 3       199.0         290,4      58,29        -20,71             9,27   8000
# 4       468.0         152,1       0,00           6,6             4,05  19000
# 5         NaN           9,7       0,13             0           191,19   1900
# 6         NaN         132,1      59,80         10,76            21,03   8600
# 7         NaN         156,0      34,54         -6,15            19,46  11000
# 8         NaN          14,4       0,18          0,61            15,18  11200
# 9     29800.0          99,9       0,00         -6,47            23,28   3500
# 10      193.0         372,5      35,49             0             5,89  28000
# 11  7686850.0           2,6       0,34          3,98             4,69  29000
# 12    83870.0          97,7       0,00             2             4,66  30000
# 13    86600.0          91,9       0,00          -4,9            81,74   3400
# 14    13940.0          21,8      25,41          -2,2            25,21  16700
# 15      665.0        1050,5      24,21          1,05            17,27  16900
# 16   144000.0        1023,4       0,40         -0,71             62,6   1900
# 17      431.0         649,5      22,51         -0,31             12,5  15700
# 18   207600.0          49,6       0,00          2,54            13,37   6100
#
#    Literacy Phones Arable Crops  Other  Climate Birthrate Deathrate  \
# 0      36,0    3,2  12,13  0,22  87,65      1.0      46,6     20,34
# 1      86,5   71,2  21,09  4,42  74,49      3.0     15,11      5,22
# 2      70,0   78,1   3,22  0,25  96,53      1.0     17,14      4,61
# 3      97,0  259,5     10    15     75      2.0     22,46      3,27
# 4     100,0  497,2   2,22     0  97,78      3.0      8,71      6,25
# 5      42,0    7,8   2,41  0,24  97,35      NaN     45,11      24,2
# 6      95,0  460,0      0     0    100      2.0     14,17      5,34
# 7      89,0  549,9  18,18  4,55  77,27      2.0     16,93      5,37
# 8      97,1  220,4  12,31  0,48  87,21      3.0     16,73      7,55
# 9      98,6  195,7  17,55   2,3  80,15      4.0     12,07      8,23
# 10     97,0  516,1  10,53     0  89,47      2.0     11,03      6,68
# 11    100,0  565,5   6,55  0,04  93,41      1.0     12,14      7,51
# 12     98,0  452,2  16,91  0,86  82,23      3.0      8,74      9,76
# 13     97,0  137,1  19,63  2,71  77,66      1.0     20,74      9,75
# 14     95,6  460,6    0,8   0,4   98,8      2.0     17,57      9,05
# 15     89,1  281,3   2,82  5,63  91,55      1.0      17,8      4,14
# 16     43,1    7,3  62,11  3,07  34,82      2.0      29,8      8,27
# 17     97,4  481,9  37,21  2,33  60,46      2.0     12,71      8,67
# 18     99,6  319,1  29,55   0,6  69,85      4.0     11,16     14,02
#
#    Agriculture Industry Service
# 0         0,38     0,24    0,38
# 1        0,232    0,188   0,579
# 2        0,101      0,6   0,298
# 3          NaN      NaN     NaN
# 4          NaN      NaN     NaN
# 5        0,096    0,658   0,246
# 6         0,04     0,18    0,78
# 7        0,038     0,22   0,743
# 8        0,095    0,358   0,547
# 9        0,239    0,343   0,418
# 10       0,004    0,333   0,663
# 11       0,038    0,262     0,7
# 12       0,018    0,304   0,678
# 13       0,141    0,457   0,402
# 14        0,03     0,07     0,9
# 15       0,005    0,387   0,608
# 16       0,199    0,198   0,603
# 17        0,06     0,16    0,78
# 18       0,093    0,316   0,591

# %% [markdown]
# # In pandas, isnull() is a function (and also a method of DataFrames and Series) used to detect missing values in your data. It returns a boolean mask where True indicates a missing value and False indicates a non-missing value.

# %%
pd.read_csv("C:\\Users\\User\\Downloads\\countries of the world.csv").isnull()
# Out:
#     Country  Region  Population   Area  Pop. Density   Coastline   \
# 0     False   False       False  False          False       False
# 1     False   False       False  False          False       False
# 2     False    True       False  False          False       False
# 3     False   False       False  False          False       False
# 4     False   False       False  False          False       False
# 5     False   False       False  False          False       False
# 6     False   False       False  False          False       False
# 7     False   False       False   True          False       False
# 8     False   False       False  False          False       False
# 9     False   False       False  False          False       False
# 10    False   False       False  False          False       False
# 11    False   False       False  False          False       False
# 12    False   False       False  False          False       False
# 13    False   False       False  False          False       False
# 14    False   False       False  False          False       False
# 15    False   False       False  False          False       False
# 16    False   False       False  False          False       False
# 17    False   False       False  False          False       False
# 18    False   False       False  False          False       False
#
#     Net migration  Infant mortality   GDP   Literacy  Phones  Arable  Crops  \
# 0           False             False  False     False   False   False  False
# 1           False             False  False     False   False   False  False
# 2           False             False  False     False   False   False  False
# 3           False             False  False     False   False   False  False
# 4           False             False  False     False   False   False  False
# 5           False             False  False     False   False   False  False
# 6           False             False  False     False   False   False  False
# 7           False             False  False     False   False   False  False
# 8           False             False  False     False   False   False  False
# 9           False             False  False     False   False   False  False
# 10          False             False  False     False   False   False  False
# 11          False             False  False     False   False   False  False
# 12          False             False  False     False   False   False  False
# 13          False             False  False     False   False   False  False
# 14          False             False  False     False   False   False  False
# 15          False             False  False     False   False   False  False
# 16          False             False  False     False   False   False  False
# 17          False             False  False     False   False   False  False
# 18          False             False  False     False   False   False  False
#
#     Other  Climate  Birthrate  Deathrate  Agriculture  Industry  Service
# 0   False    False      False      False        False     False    False
# 1   False    False      False      False        False     False    False
# 2   False    False      False      False        False     False    False
# 3   False    False      False      False         True      True     True
# 4   False    False      False      False         True      True     True
# 5   False     True      False      False        False     False    False
# 6   False    False      False      False        False     False    False
# 7   False    False      False      False        False     False    False
# 8   False    False      False      False        False     False    False
# 9   False    False      False      False        False     False    False
# 10  False    False      False      False        False     False    False
# 11  False    False      False      False        False     False    False
# 12  False    False      False      False        False     False    False
# 13  False    False      False      False        False     False    False
# 14  False    False      False      False        False     False    False
# 15  False    False      False      False        False     False    False
# 16  False    False      False      False        False     False    False
# 17  False    False      False      False        False     False    False
# 18  False    False      False      False        False     False    False

# %%
df = pd.read_csv("C:\\Users\\User\\Downloads\\countries of the world 2.csv").isnull()

# %% [markdown]
# # To count the total number of null values in each column of a DataFrame

# %%
pd.read_csv("C:\\Users\\User\\Downloads\\countries of the world 2.csv").isnull().sum()
# Out:
# Country             0
# Region              4
# Population          0
# Area                4
# Pop. Density        0
# Coastline           0
# Net migration       0
# Infant mortality    0
# GDP                 0
# Literacy            0
# Phones              0
# Arable              0
# Crops               0
# Other               0
# Climate             1
# Birthrate           0
# Deathrate           0
# Agriculture         2
# Industry            2
# Service             2
# dtype: int64

# %% [markdown]
# # To count the total number of null values in a DataFrame

# %%
pd.read_csv("C:\\Users\\User\\Downloads\\countries of the world 2.csv").isnull().sum().sum()
# Out:
# np.int64(15)

# %% [markdown]
# # In pandas, notnull() is a function (and also a method of DataFrames and Series) used to detect non-missing values in your data. It returns a boolean mask where True indicates a non-missing value and False indicates a missing value.

# %%
pd.read_csv("C:\\Users\\User\\Downloads\\countries of the world 2.csv").notnull()
# Out:
#     Country  Region  Population   Area  Pop. Density   Coastline   \
# 0      True    True        True   True           True        True
# 1      True   False        True   True           True        True
# 2      True   False        True   True           True        True
# 3      True   False        True   True           True        True
# 4      True   False        True   True           True        True
# 5      True    True        True  False           True        True
# 6      True    True        True  False           True        True
# 7      True    True        True  False           True        True
# 8      True    True        True  False           True        True
# 9      True    True        True   True           True        True
# 10     True    True        True   True           True        True
# 11     True    True        True   True           True        True
# 12     True    True        True   True           True        True
# 13     True    True        True   True           True        True
# 14     True    True        True   True           True        True
# 15     True    True        True   True           True        True
# 16     True    True        True   True           True        True
# 17     True    True        True   True           True        True
# 18     True    True        True   True           True        True
#
#     Net migration  Infant mortality  GDP   Literacy  Phones  Arable  Crops  \
# 0            True              True  True      True    True    True   True
# 1            True              True  True      True    True    True   True
# 2            True              True  True      True    True    True   True
# 3            True              True  True      True    True    True   True
# 4            True              True  True      True    True    True   True
# 5            True              True  True      True    True    True   True
# 6            True              True  True      True    True    True   True
# 7            True              True  True      True    True    True   True
# 8            True              True  True      True    True    True   True
# 9            True              True  True      True    True    True   True
# 10           True              True  True      True    True    True   True
# 11           True              True  True      True    True    True   True
# 12           True              True  True      True    True    True   True
# 13           True              True  True      True    True    True   True
# 14           True              True  True      True    True    True   True
# 15           True              True  True      True    True    True   True
# 16           True              True  True      True    True    True   True
# 17           True              True  True      True    True    True   True
# 18           True              True  True      True    True    True   True
#
#     Other  Climate  Birthrate  Deathrate  Agriculture  Industry  Service
# 0    True     True       True       True         True      True     True
# 1    True     True       True       True         True      True     True
# 2    True     True       True       True         True      True     True
# 3    True     True       True       True        False     False    False
# 4    True     True       True       True        False     False    False
# 5    True    False       True       True         True      True     True
# 6    True     True       True       True         True      True     True
# 7    True     True       True       True         True      True     True
# 8    True     True       True       True         True      True     True
# 9    True     True       True       True         True      True     True
# 10   True     True       True       True         True      True     True
# 11   True     True       True       True         True      True     True
# 12   True     True       True       True         True      True     True
# 13   True     True       True       True         True      True     True
# 14   True     True       True       True         True      True     True
# 15   True     True       True       True         True      True     True
# 16   True     True       True       True         True      True     True
# 17   True     True       True       True         True      True     True
# 18   True     True       True       True         True      True     True

# %% [markdown]
# # To count the total number of notnull values in each column of a DataFrame

# %%
pd.read_csv("C:\\Users\\User\\Downloads\\countries of the world 2.csv").notnull().sum()
# Out:
# Country             19
# Region              15
# Population          19
# Area                15
# Pop. Density        19
# Coastline           19
# Net migration       19
# Infant mortality    19
# GDP                 19
# Literacy            19
# Phones              19
# Arable              19
# Crops               19
# Other               19
# Climate             18
# Birthrate           19
# Deathrate           19
# Agriculture         17
# Industry            17
# Service             17
# dtype: int64

# %% [markdown]
# # To count the total number of notnull values in a DataFrame

# %%
pd.read_csv("C:\\Users\\User\\Downloads\\countries of the world 2.csv").notnull().sum().sum()
# Out:
# np.int64(365)

# %%
import numpy as np
pd.Series([1,2,3,np.nan,10,30,40,np.nan,50])
# Out:
# 0     1.0
# 1     2.0
# 2     3.0
# 3     NaN
# 4    10.0
# 5    30.0
# 6    40.0
# 7     NaN
# 8    50.0
# dtype: float64

# %%
pd.Series([1,2,3,np.nan,10,30,40,np.nan,50]).isnull()
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5    False
# 6    False
# 7     True
# 8    False
# dtype: bool

# %% [markdown]
# # To count the total number of null values in each column of a Series

# %%
pd.Series([1,2,3,np.nan,10,30,40,np.nan,50]).isnull().sum()
# Out:
# np.int64(2)

# %% [markdown]
# # To count the total number of null values in a Series

# %%
pd.Series([1,2,3,np.nan,10,30,40,np.nan,50]).isnull().sum().sum()
# Out:
# np.int64(2)

# %%
pd.Series([1,2,3,np.nan,10,30,40,np.nan,50]).notnull()
# Out:
# 0     True
# 1     True
# 2     True
# 3    False
# 4     True
# 5     True
# 6     True
# 7    False
# 8     True
# dtype: bool

# %% [markdown]
# # To count the total number of notnull values in each column of a Series

# %%
pd.Series([1,2,3,np.nan,10,30,40,np.nan,50]).notnull().sum()
# Out:
# np.int64(7)

# %% [markdown]
# # To count the total number of notnull values in a Series

# %%
pd.Series([1,2,3,np.nan,10,30,40,np.nan,50]).notnull().sum().sum()
# Out:
# np.int64(7)

# %%
pd.read_csv("C:\\Users\\User\\Downloads\\Book6.csv")
# Out:
#   Countries Name        Capital Language Spoken
# 0            USA  Washington DC         English
# 1         France          Paris             NaN
# 2          Japan          Tokyo             NaN
# 3         Canada         Ottawa             NaN

# %%
pd.read_csv("C:\\Users\\User\\Downloads\\Book6.csv")
# Out:
#   Countries Name        Capital Language Spoken
# 0            USA  Washington DC         English
# 1         France          Paris             NaN
# 2          Japan          Tokyo             NaN
# 3         Canada         Ottawa             NaN

# %% [markdown]
# # In Pandas, the dropna() function is used to remove rows or columns containing missing values (NaN) from a DataFrame.

# %%
pd.read_csv("C:\\Users\\User\\Downloads\\Book6.csv").dropna()
# Out:
#   Countries Name        Capital Language Spoken
# 0            USA  Washington DC         English

# %%
pd.read_csv("C:\\Users\\User\\Downloads\\Book6.csv")
# Out:
#   Countries Name        Capital Language Spoken
# 0            USA  Washington DC         English
# 1         France          Paris             NaN
# 2          Japan          Tokyo             NaN
# 3         Canada         Ottawa             NaN

# %% [markdown]
# # Parameters in dropna():-

# %% [markdown]
# # axis:
# # 0 or 'index': Drop rows with missing values.
# # 1 or 'columns': Drop columns with missing values.

# %%
pd.read_csv("C:\\Users\\User\\Downloads\\Book6.csv").dropna(axis=1)
# Out:
#   Countries Name        Capital
# 0            USA  Washington DC
# 1         France          Paris
# 2          Japan          Tokyo
# 3         Canada         Ottawa

# %% [markdown]
# # how parameter in drop_na() function consists of two inputs which are 'any' and 'all'.
# # how:
# # 'any': Drop the row/column if any value is missing.
# # 'all': Drop the row/column only if all values are missing.

# %%
pd.read_csv("C:\\Users\\User\\Downloads\\Book6.csv").dropna(how = 'any')
# Out:
#   Countries Name        Capital Language Spoken
# 0            USA  Washington DC         English

# %%
pd.read_csv("C:\\Users\\User\\Downloads\\Book6.csv").dropna(axis = 1,how = 'any')
# Out:
#   Countries Name        Capital
# 0            USA  Washington DC
# 1         France          Paris
# 2          Japan          Tokyo
# 3         Canada         Ottawa

# %%
pd.read_csv("C:\\Users\\User\\Downloads\\Book6.csv").dropna(how = 'all')
# Out:
#   Countries Name        Capital Language Spoken
# 0            USA  Washington DC         English
# 1         France          Paris             NaN
# 2          Japan          Tokyo             NaN
# 3         Canada         Ottawa             NaN

# %%
pd.read_csv("C:\\Users\\User\\Downloads\\Book6.csv")
# Out:
#   Countries Name        Capital Language Spoken
# 0            USA  Washington DC         English
# 1         France          Paris             NaN
# 2          Japan          Tokyo             NaN
# 3         Canada         Ottawa             NaN

# %%
pd.read_csv("C:\\Users\\User\\Downloads\\Book6.csv").dropna(axis = 1,how = 'all')
# Out:
#   Countries Name        Capital Language Spoken
# 0            USA  Washington DC         English
# 1         France          Paris             NaN
# 2          Japan          Tokyo             NaN
# 3         Canada         Ottawa             NaN

# %%
pd.read_csv("C:\\Users\\User\\Downloads\\Book7.csv")
# Out:
#   Countries Name Capital  Language Spoken
# 0            NaN     NaN              NaN
# 1         France   Paris              NaN
# 2          Japan   Tokyo              NaN
# 3         Canada  Ottawa              NaN

# %%
pd.read_csv("C:\\Users\\User\\Downloads\\Book7.csv").dropna(how = 'all')
# Out:
#   Countries Name Capital  Language Spoken
# 1         France   Paris              NaN
# 2          Japan   Tokyo              NaN
# 3         Canada  Ottawa              NaN

# %%
pd.read_csv("C:\\Users\\User\\Downloads\\Book7.csv").dropna(axis = 1,how = 'all')
# Out:
#   Countries Name Capital
# 0            NaN     NaN
# 1         France   Paris
# 2          Japan   Tokyo
# 3         Canada  Ottawa

# %% [markdown]
# # thresh:
# # An integer value specifying the minimum number of non-NA values required to keep the row/column.

# %%
pd.read_csv("C:\\Users\\User\\Downloads\\Book7.csv")
# Out:
#   Countries Name Capital  Language Spoken
# 0            NaN     NaN              NaN
# 1         France   Paris              NaN
# 2          Japan   Tokyo              NaN
# 3         Canada  Ottawa              NaN

# %%
pd.read_csv("C:\\Users\\User\\Downloads\\Book7.csv").dropna(thresh=1)
# Out:
#   Countries Name Capital  Language Spoken
# 1         France   Paris              NaN
# 2          Japan   Tokyo              NaN
# 3         Canada  Ottawa              NaN

# %%
pd.read_csv("C:\\Users\\User\\Downloads\\Book7.csv").dropna(thresh=4)
# Out:
# Empty DataFrame
# Columns: [Countries Name, Capital, Language Spoken]
# Index: []

# %%
pd.read_csv("C:\\Users\\User\\Downloads\\Book7.csv").dropna(axis=1,thresh=1)
# Out:
#   Countries Name Capital
# 0            NaN     NaN
# 1         France   Paris
# 2          Japan   Tokyo
# 3         Canada  Ottawa

# %%
pd.read_csv("C:\\Users\\User\\Downloads\\Book7.csv").dropna(axis=1,thresh=4)
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3]

# %%
pd.read_csv("C:\\Users\\User\\Downloads\\Book7.csv")
# Out:
#   Countries Name Capital  Language Spoken
# 0            NaN     NaN              NaN
# 1         France   Paris              NaN
# 2          Japan   Tokyo              NaN
# 3         Canada  Ottawa              NaN

# %% [markdown]
# # subset:
# # A list of column labels to consider for missing values.

# %%
pd.read_csv("C:\\Users\\User\\Downloads\\Book7.csv").dropna(subset = 'Countries Name')
# Out:
#   Countries Name Capital  Language Spoken
# 1         France   Paris              NaN
# 2          Japan   Tokyo              NaN
# 3         Canada  Ottawa              NaN

# %%
pd.read_csv("C:\\Users\\User\\Downloads\\Book7.csv").dropna(subset = 'Capital')
# Out:
#   Countries Name Capital  Language Spoken
# 1         France   Paris              NaN
# 2          Japan   Tokyo              NaN
# 3         Canada  Ottawa              NaN

# %%
pd.read_csv("C:\\Users\\User\\Downloads\\Book7.csv").dropna(subset = 'Language Spoken')
# Out:
# Empty DataFrame
# Columns: [Countries Name, Capital, Language Spoken]
# Index: []

# %%
pd.read_csv("C:\\Users\\User\\Downloads\\Book7.csv")
# Out:
#   Countries Name Capital  Language Spoken
# 0            NaN     NaN              NaN
# 1         France   Paris              NaN
# 2          Japan   Tokyo              NaN
# 3         Canada  Ottawa              NaN

# %% [markdown]
# # inplace:
# # If True, modifies the DataFrame directly. If False (default), returns a new DataFrame.

# %%
df = pd.read_csv("C:\\Users\\User\\Downloads\\Book7.csv")
df.dropna(inplace=False)
df
# Out:
#   Countries Name Capital  Language Spoken
# 0            NaN     NaN              NaN
# 1         France   Paris              NaN
# 2          Japan   Tokyo              NaN
# 3         Canada  Ottawa              NaN

# %%
df = pd.read_csv("C:\\Users\\User\\Downloads\\Book7.csv")
df.dropna(inplace=True)
df
# Out:
# Empty DataFrame
# Columns: [Countries Name, Capital, Language Spoken]
# Index: []

# %%
pd.read_csv("C:\\Users\\User\\Downloads\\Book7.csv")
# Out:
#   Countries Name Capital  Language Spoken
# 0            NaN     NaN              NaN
# 1         France   Paris              NaN
# 2          Japan   Tokyo              NaN
# 3         Canada  Ottawa              NaN

# %% [markdown]
# # In Pandas, the fillna() method is used to fill missing values (represented by NaN) in a DataFrame or Series with specified values.

# %% [markdown]
# # Parameters in fillna():-

# %% [markdown]
# # value: The value to use to fill the missing data. This can be a scalar value, a dictionary, or a Series.

# %%
pd.read_csv("C:\\Users\\User\\Downloads\\Book7.csv").fillna(0)
# Out:
#   Countries Name Capital  Language Spoken
# 0              0       0              0.0
# 1         France   Paris              0.0
# 2          Japan   Tokyo              0.0
# 3         Canada  Ottawa              0.0

# %%
pd.read_csv("C:\\Users\\User\\Downloads\\Book7.csv").fillna(2)
# Out:
#   Countries Name Capital  Language Spoken
# 0              2       2              2.0
# 1         France   Paris              2.0
# 2          Japan   Tokyo              2.0
# 3         Canada  Ottawa              2.0

# %%
 pd.read_csv("C:\\Users\\User\\Downloads\\Book7.csv").fillna({'Countries Name':'None','Capital':1,'Language Spoken':0})
# Out:
#   Countries Name Capital  Language Spoken
# 0           None       1              0.0
# 1         France   Paris              0.0
# 2          Japan   Tokyo              0.0
# 3         Canada  Ottawa              0.0

# %%
pd.read_csv("C:\\Users\\User\\Downloads\\Book6.csv")
# Out:
#   Countries Name        Capital Language Spoken
# 0            USA  Washington DC         English
# 1         France          Paris             NaN
# 2          Japan          Tokyo             NaN
# 3         Canada         Ottawa             NaN

# %% [markdown]
# # method: The method to use for filling missing values. Options are 'ffill' (forward fill), 'bfill' (backward fill), or None (default, which uses the value parameter).

# %%
pd.read_csv("C:\\Users\\User\\Downloads\\Book6.csv").fillna(method='ffill')
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_11752\4069250240.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   pd.read_csv("C:\\Users\\User\\Downloads\\Book6.csv").fillna(method='ffill')
#   Countries Name        Capital Language Spoken
# 0            USA  Washington DC         English
# 1         France          Paris         English
# 2          Japan          Tokyo         English
# 3         Canada         Ottawa         English

# %%
pd.read_csv("C:\\Users\\User\\Downloads\\Book6.csv").fillna(method='pad')
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_11752\4285624325.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   pd.read_csv("C:\\Users\\User\\Downloads\\Book6.csv").fillna(method='pad')
#   Countries Name        Capital Language Spoken
# 0            USA  Washington DC         English
# 1         France          Paris         English
# 2          Japan          Tokyo         English
# 3         Canada         Ottawa         English

# %%
pd.read_csv("C:\\Users\\User\\Downloads\\Book7.csv").fillna(method='bfill')
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_11752\3242343399.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   pd.read_csv("C:\\Users\\User\\Downloads\\Book7.csv").fillna(method='bfill')
#   Countries Name Capital  Language Spoken
# 0         France   Paris              NaN
# 1         France   Paris              NaN
# 2          Japan   Tokyo              NaN
# 3         Canada  Ottawa              NaN

# %% [markdown]
# # axis: The axis along which to fill missing values (0 for rows, 1 for columns).

# %%
pd.read_csv("C:\\Users\\User\\Downloads\\Book6.csv").fillna(method='ffill',axis=0)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_11752\2257802132.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   pd.read_csv("C:\\Users\\User\\Downloads\\Book6.csv").fillna(method='ffill',axis=0)
#   Countries Name        Capital Language Spoken
# 0            USA  Washington DC         English
# 1         France          Paris         English
# 2          Japan          Tokyo         English
# 3         Canada         Ottawa         English

# %%
pd.read_csv("C:\\Users\\User\\Downloads\\Book6.csv").fillna(method='ffill',axis=1)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_11752\1555450516.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   pd.read_csv("C:\\Users\\User\\Downloads\\Book6.csv").fillna(method='ffill',axis=1)
#   Countries Name        Capital Language Spoken
# 0            USA  Washington DC         English
# 1         France          Paris           Paris
# 2          Japan          Tokyo           Tokyo
# 3         Canada         Ottawa          Ottawa

# %%
pd.read_csv("C:\\Users\\User\\Downloads\\Book8.csv")
# Out:
#   Countries Name  Capital Language Spoken
# 0            USA      NaN         English
# 1         France      NaN         English
# 2          Japan      NaN        Japanese
# 3         Canada      NaN        Canadian

# %%
pd.read_csv("C:\\Users\\User\\Downloads\\Book8.csv").fillna(method='bfill',axis=1)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_11752\1776020817.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   pd.read_csv("C:\\Users\\User\\Downloads\\Book8.csv").fillna(method='bfill',axis=1)
#   Countries Name   Capital Language Spoken
# 0            USA   English         English
# 1         France   English         English
# 2          Japan  Japanese        Japanese
# 3         Canada  Canadian        Canadian

# %%
pd.read_csv("C:\\Users\\User\\Downloads\\Book7.csv")
# Out:
#   Countries Name Capital  Language Spoken
# 0            NaN     NaN              NaN
# 1         France   Paris              NaN
# 2          Japan   Tokyo              NaN
# 3         Canada  Ottawa              NaN

# %% [markdown]
# # limit: The maximum number of consecutive missing values to fill.

# %%
pd.read_csv("C:\\Users\\User\\Downloads\\Book7.csv").fillna(0,limit=1)
# Out:
#   Countries Name Capital  Language Spoken
# 0              0       0              0.0
# 1         France   Paris              NaN
# 2          Japan   Tokyo              NaN
# 3         Canada  Ottawa              NaN

# %%
pd.read_csv("C:\\Users\\User\\Downloads\\Book7.csv").fillna(0,limit=2)
# Out:
#   Countries Name Capital  Language Spoken
# 0              0       0              0.0
# 1         France   Paris              0.0
# 2          Japan   Tokyo              NaN
# 3         Canada  Ottawa              NaN

# %%
pd.read_csv("C:\\Users\\User\\Downloads\\Book6.csv").fillna(method='ffill',limit=1)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_11752\2070965173.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   pd.read_csv("C:\\Users\\User\\Downloads\\Book6.csv").fillna(method='ffill',limit=1)
#   Countries Name        Capital Language Spoken
# 0            USA  Washington DC         English
# 1         France          Paris         English
# 2          Japan          Tokyo             NaN
# 3         Canada         Ottawa             NaN

# %%
pd.read_csv("C:\\Users\\User\\Downloads\\Book6.csv").fillna(method='ffill',limit=2)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_11752\4088641586.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   pd.read_csv("C:\\Users\\User\\Downloads\\Book6.csv").fillna(method='ffill',limit=2)
#   Countries Name        Capital Language Spoken
# 0            USA  Washington DC         English
# 1         France          Paris         English
# 2          Japan          Tokyo         English
# 3         Canada         Ottawa             NaN

# %%
dataframe = pd.read_csv("C:\\Users\\User\\Downloads\\Book6.csv")

# %% [markdown]
# # inplace: If True, the DataFrame is modified in place. If False (default), a new DataFrame is returned.

# %%
dataframe.fillna(1,inplace=True)
dataframe
# Out:
#   Countries Name        Capital Language Spoken
# 0            USA  Washington DC         English
# 1         France          Paris               1
# 2          Japan          Tokyo               1
# 3         Canada         Ottawa               1

# %%
dataframe
# Out:
#   Countries Name        Capital Language Spoken
# 0            USA  Washington DC         English
# 1         France          Paris               1
# 2          Japan          Tokyo               1
# 3         Canada         Ottawa               1

# %%
pd.read_csv("C:\\Users\\User\\Downloads\\Book9.csv")
# Out:
#    ID         Product Name Shipper Name
# 0   1      Croma Stand Fan        FedEx
# 1   2    Daikin AC 1 tonne         DTDC
# 2   3  Polycab Ceiling Fan         DTDC

# %% [markdown]
# # In Pandas, the replace() method can be used to replace values in a DataFrame or Series.

# %% [markdown]
# # Parameters in replace():-

# %% [markdown]
# # to_replace:
# # The value or values to be replaced. Can be a single value, a list, a dictionary, or a regular expression.

# %% [markdown]
# # value:
# # The new value to replace with. Can be a single value or a dictionary.

# %%
pd.read_csv("C:\\Users\\User\\Downloads\\Book9.csv").replace(to_replace='DTDC',value='Carrier')
# Out:
#    ID         Product Name Shipper Name
# 0   1      Croma Stand Fan        FedEx
# 1   2    Daikin AC 1 tonne      Carrier
# 2   3  Polycab Ceiling Fan      Carrier

# %%
pd.read_csv("C:\\Users\\User\\Downloads\\Book9.csv").replace('DTDC','Carrier')
# Out:
#    ID         Product Name Shipper Name
# 0   1      Croma Stand Fan        FedEx
# 1   2    Daikin AC 1 tonne      Carrier
# 2   3  Polycab Ceiling Fan      Carrier

# %%
pd.read_csv("C:\\Users\\User\\Downloads\\Book9.csv").replace(to_replace=1,value=101)
# Out:
#     ID         Product Name Shipper Name
# 0  101      Croma Stand Fan        FedEx
# 1    2    Daikin AC 1 tonne         DTDC
# 2    3  Polycab Ceiling Fan         DTDC

# %%
pd.read_csv("C:\\Users\\User\\Downloads\\Book9.csv").replace(to_replace=[1,2,3],value=0)
# Out:
#    ID         Product Name Shipper Name
# 0   0      Croma Stand Fan        FedEx
# 1   0    Daikin AC 1 tonne         DTDC
# 2   0  Polycab Ceiling Fan         DTDC

# %%
pd.read_csv("C:\\Users\\User\\Downloads\\Book9.csv").replace([1,2,3],0)
# Out:
#    ID         Product Name Shipper Name
# 0   0      Croma Stand Fan        FedEx
# 1   0    Daikin AC 1 tonne         DTDC
# 2   0  Polycab Ceiling Fan         DTDC

# %%
pd.read_csv("C:\\Users\\User\\Downloads\\Book9.csv").replace(to_replace=[1,2,3],value=[101,102,103])
# Out:
#     ID         Product Name Shipper Name
# 0  101      Croma Stand Fan        FedEx
# 1  102    Daikin AC 1 tonne         DTDC
# 2  103  Polycab Ceiling Fan         DTDC

# %%
pd.read_csv("C:\\Users\\User\\Downloads\\Book9.csv").replace([1,2,3],[101,102,103])
# Out:
#     ID         Product Name Shipper Name
# 0  101      Croma Stand Fan        FedEx
# 1  102    Daikin AC 1 tonne         DTDC
# 2  103  Polycab Ceiling Fan         DTDC

# %%
pd.read_csv("C:\\Users\\User\\Downloads\\Book9.csv").replace({'Shipper Name':'DTDC'},'none')
# Out:
#    ID         Product Name Shipper Name
# 0   1      Croma Stand Fan        FedEx
# 1   2    Daikin AC 1 tonne         none
# 2   3  Polycab Ceiling Fan         none

# %%
pd.read_csv("C:\\Users\\User\\Downloads\\Book9.csv").replace({'Shipper Name':'DTDC','Product Name':'Daikin AC 1 tonne'},'none')
# Out:
#    ID         Product Name Shipper Name
# 0   1      Croma Stand Fan        FedEx
# 1   2                 none         none
# 2   3  Polycab Ceiling Fan         none

# %%
pd.read_csv("C:\\Users\\User\\Downloads\\Book9.csv")
# Out:
#    ID         Product Name Shipper Name
# 0   1      Croma Stand Fan        FedEx
# 1   2    Daikin AC 1 tonne         DTDC
# 2   3  Polycab Ceiling Fan         DTDC

# %% [markdown]
# # regex: If True, to_replace is interpreted as a regular expression.

# %%
pd.read_csv("C:\\Users\\User\\Downloads\\Book9.csv").replace('[A-Za-z]',0,regex=True)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_11752\2377904405.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   pd.read_csv("C:\\Users\\User\\Downloads\\Book9.csv").replace('[A-Za-z]',0,regex=True)
#    ID  Product Name  Shipper Name
# 0   1             0             0
# 1   2             0             0
# 2   3             0             0

# %%
pd.read_csv("C:\\Users\\User\\Downloads\\Book9.csv").replace({'Shipper Name':'[A-Za-z]'},0,regex=True)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_11752\311821927.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   pd.read_csv("C:\\Users\\User\\Downloads\\Book9.csv").replace({'Shipper Name':'[A-Za-z]'},0,regex=True)
#    ID         Product Name  Shipper Name
# 0   1      Croma Stand Fan             0
# 1   2    Daikin AC 1 tonne             0
# 2   3  Polycab Ceiling Fan             0

# %%
pd.read_csv("C:\\Users\\User\\Downloads\\Book9.csv")
# Out:
#    ID         Product Name Shipper Name
# 0   1      Croma Stand Fan        FedEx
# 1   2    Daikin AC 1 tonne         DTDC
# 2   3  Polycab Ceiling Fan         DTDC

# %% [markdown]
# # method: It is used for forward or backward filling if to_replace is a list and value is None.

# %%
pd.read_csv("C:\\Users\\User\\Downloads\\Book9.csv").replace('DTDC',method='ffill')
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_11752\3701097730.py:1: FutureWarning: The 'method' keyword in DataFrame.replace is deprecated and will be removed in a future version.
#   pd.read_csv("C:\\Users\\User\\Downloads\\Book9.csv").replace('DTDC',method='ffill')
#    ID         Product Name Shipper Name
# 0   1      Croma Stand Fan        FedEx
# 1   2    Daikin AC 1 tonne        FedEx
# 2   3  Polycab Ceiling Fan        FedEx

# %%
pd.read_csv("C:\\Users\\User\\Downloads\\Book9.csv")
# Out:
#    ID         Product Name Shipper Name
# 0   1      Croma Stand Fan        FedEx
# 1   2    Daikin AC 1 tonne         DTDC
# 2   3  Polycab Ceiling Fan         DTDC

# %%
pd.read_csv("C:\\Users\\User\\Downloads\\Book9.csv").replace('FedEx',method='bfill')
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_11752\3062972711.py:1: FutureWarning: The 'method' keyword in DataFrame.replace is deprecated and will be removed in a future version.
#   pd.read_csv("C:\\Users\\User\\Downloads\\Book9.csv").replace('FedEx',method='bfill')
#    ID         Product Name Shipper Name
# 0   1      Croma Stand Fan         DTDC
# 1   2    Daikin AC 1 tonne         DTDC
# 2   3  Polycab Ceiling Fan         DTDC

# %%
pd.read_csv("C:\\Users\\User\\Downloads\\Book9.csv")
# Out:
#    ID         Product Name Shipper Name
# 0   1      Croma Stand Fan        FedEx
# 1   2    Daikin AC 1 tonne         DTDC
# 2   3  Polycab Ceiling Fan         DTDC

# %% [markdown]
# # limit: The maximum number of replacements to make in each column.

# %%
pd.read_csv("C:\\Users\\User\\Downloads\\Book9.csv").replace("DTDC",method='ffill',limit=1)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_11752\1136855098.py:1: FutureWarning: The 'method' keyword in DataFrame.replace is deprecated and will be removed in a future version.
#   pd.read_csv("C:\\Users\\User\\Downloads\\Book9.csv").replace("DTDC",method='ffill',limit=1)
#    ID         Product Name Shipper Name
# 0   1      Croma Stand Fan        FedEx
# 1   2    Daikin AC 1 tonne        FedEx
# 2   3  Polycab Ceiling Fan         DTDC

# %%
pd.read_csv("C:\\Users\\User\\Downloads\\Book9.csv").replace("FedEx",method='bfill',limit=1)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_11752\1911521573.py:1: FutureWarning: The 'method' keyword in DataFrame.replace is deprecated and will be removed in a future version.
#   pd.read_csv("C:\\Users\\User\\Downloads\\Book9.csv").replace("FedEx",method='bfill',limit=1)
#    ID         Product Name Shipper Name
# 0   1      Croma Stand Fan         DTDC
# 1   2    Daikin AC 1 tonne         DTDC
# 2   3  Polycab Ceiling Fan         DTDC

# %%
data = pd.read_csv("C:\\Users\\User\\Downloads\\Book9.csv")
data
# Out:
#    ID         Product Name Shipper Name
# 0   1      Croma Stand Fan        FedEx
# 1   2    Daikin AC 1 tonne         DTDC
# 2   3  Polycab Ceiling Fan         DTDC

# %% [markdown]
# # inplace: If True, the DataFrame is modified in place. If False (default), a new DataFrame is returned.

# %%
data.replace('DTDC','FedEx',inplace=True)
data
# Out:
#    ID         Product Name Shipper Name
# 0   1      Croma Stand Fan        FedEx
# 1   2    Daikin AC 1 tonne        FedEx
# 2   3  Polycab Ceiling Fan        FedEx

# %%
data
# Out:
#    ID         Product Name Shipper Name
# 0   1      Croma Stand Fan        FedEx
# 1   2    Daikin AC 1 tonne        FedEx
# 2   3  Polycab Ceiling Fan        FedEx

# %%
pd.read_csv("C:\\Users\\User\\Downloads\\Book10.csv")
# Out:
#    Rank    Type of Train  Velocity
# 0   1.0  Aerospace Train    1200.0
# 1   NaN     Bullet Train     600.0
# 2   3.0              NaN       NaN
# 3   4.0    Express Train     200.0

# %% [markdown]
# # In Pandas, interpolate() function is basically used to fill NaN values in dataframe or series.

# %%
pd.read_csv("C:\\Users\\User\\Downloads\\Book10.csv").interpolate()
df.interpolate()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_11752\1330135191.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   pd.read_csv("C:\\Users\\User\\Downloads\\Book10.csv").interpolate()
#    Rank    Type of Train  Velocity
# 0   1.0  Aerospace Train    1200.0
# 1   2.0     Bullet Train     600.0
# 2   3.0              NaN     400.0
# 3   4.0    Express Train     200.0

# %% [markdown]
# # Parameters in interpolate():-

# %% [markdown]
# # Method: The method parameter specifies the interpolation technique to use. The default is 'linear', which performs linear interpolation between the known values.

# %%
pd.read_csv("C:\\Users\\User\\Downloads\\Book10.csv").interpolate(method='linear')
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_11752\4036587238.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   pd.read_csv("C:\\Users\\User\\Downloads\\Book10.csv").interpolate(method='linear')
#    Rank    Type of Train  Velocity
# 0   1.0  Aerospace Train    1200.0
# 1   2.0     Bullet Train     600.0
# 2   3.0              NaN     400.0
# 3   4.0    Express Train     200.0

# %%
pd.read_csv("C:\\Users\\User\\Downloads\\Book10.csv").interpolate(method='index')
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_11752\464721888.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   pd.read_csv("C:\\Users\\User\\Downloads\\Book10.csv").interpolate(method='index')
#    Rank    Type of Train  Velocity
# 0   1.0  Aerospace Train    1200.0
# 1   2.0     Bullet Train     600.0
# 2   3.0              NaN     400.0
# 3   4.0    Express Train     200.0

# %%
pd.read_csv("C:\\Users\\User\\Downloads\\Book10.csv").interpolate(method='nearest')
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_11752\3274339406.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   pd.read_csv("C:\\Users\\User\\Downloads\\Book10.csv").interpolate(method='nearest')
#    Rank    Type of Train  Velocity
# 0   1.0  Aerospace Train    1200.0
# 1   1.0     Bullet Train     600.0
# 2   3.0              NaN     600.0
# 3   4.0    Express Train     200.0

# %%
pd.read_csv("C:\\Users\\User\\Downloads\\Book10.csv").interpolate(method='polynomial',order=1)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_11752\1329983600.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   pd.read_csv("C:\\Users\\User\\Downloads\\Book10.csv").interpolate(method='polynomial',order=1)
#    Rank    Type of Train  Velocity
# 0   1.0  Aerospace Train    1200.0
# 1   2.0     Bullet Train     600.0
# 2   3.0              NaN     400.0
# 3   4.0    Express Train     200.0

# %%
pd.read_csv("C:\\Users\\User\\Downloads\\Book10.csv").interpolate(method='polynomial',order=2)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_11752\3319367067.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   pd.read_csv("C:\\Users\\User\\Downloads\\Book10.csv").interpolate(method='polynomial',order=2)
#    Rank    Type of Train     Velocity
# 0   1.0  Aerospace Train  1200.000000
# 1   2.0     Bullet Train   600.000000
# 2   3.0              NaN   266.666667
# 3   4.0    Express Train   200.000000

# %%
pd.read_csv("C:\\Users\\User\\Downloads\\Book10.csv").interpolate(method='spline',order=2)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_11752\2786608094.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   pd.read_csv("C:\\Users\\User\\Downloads\\Book10.csv").interpolate(method='spline',order=2)
#    Rank    Type of Train     Velocity
# 0   1.0  Aerospace Train  1200.000000
# 1   2.0     Bullet Train   600.000000
# 2   3.0              NaN   266.666667
# 3   4.0    Express Train   200.000000

# %%
pd.read_csv("C:\\Users\\User\\Downloads\\Book10.csv")
# Out:
#    Rank    Type of Train  Velocity
# 0   1.0  Aerospace Train    1200.0
# 1   NaN     Bullet Train     600.0
# 2   3.0              NaN       NaN
# 3   4.0    Express Train     200.0

# %%
pd.read_csv("C:\\Users\\User\\Downloads\\Book10.csv").dtypes
# Out:
# Rank             float64
# Type of Train     object
# Velocity         float64
# dtype: object

# %% [markdown]
# # axis: The axis along which to interpolate (0 for columns, 1 for rows). Default is 0.

# %%
pd.read_csv("C:\\Users\\User\\Downloads\\Book10.csv").interpolate(axis=0)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_11752\1515137431.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   pd.read_csv("C:\\Users\\User\\Downloads\\Book10.csv").interpolate(axis=0)
#    Rank    Type of Train  Velocity
# 0   1.0  Aerospace Train    1200.0
# 1   2.0     Bullet Train     600.0
# 2   3.0              NaN     400.0
# 3   4.0    Express Train     200.0

# %% [markdown]
# # limit: The limit parameter specifies the maximum number of consecutive NaN values to fill.

# %%
pd.read_csv("C:\\Users\\User\\Downloads\\Book10.csv").interpolate(limit=1)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_11752\2367139271.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   pd.read_csv("C:\\Users\\User\\Downloads\\Book10.csv").interpolate(limit=1)
#    Rank    Type of Train  Velocity
# 0   1.0  Aerospace Train    1200.0
# 1   2.0     Bullet Train     600.0
# 2   3.0              NaN     400.0
# 3   4.0    Express Train     200.0

# %%
pd.read_csv("C:\\Users\\User\\Downloads\\Book10.csv").interpolate(limit=2)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_11752\771249523.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   pd.read_csv("C:\\Users\\User\\Downloads\\Book10.csv").interpolate(limit=2)
#    Rank    Type of Train  Velocity
# 0   1.0  Aerospace Train    1200.0
# 1   2.0     Bullet Train     600.0
# 2   3.0              NaN     400.0
# 3   4.0    Express Train     200.0

# %%
pd.read_csv("C:\\Users\\User\\Downloads\\Book11.csv")
# Out:
#    Rank    Type of Train  Velocity
# 0   1.0  Aerospace Train    1200.0
# 1   NaN     Bullet Train       NaN
# 2   NaN     Maglev Train       NaN
# 3   4.0    Express Train     200.0

# %% [markdown]
# # Limit Direction: The limit_direction parameter determines the direction in which to fill the NaN values. It can be 'forward', 'backward', or 'both'.

# %%
pd.read_csv("C:\\Users\\User\\Downloads\\Book11.csv").interpolate(limit=1,limit_direction='backward')
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_11752\4089604960.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   pd.read_csv("C:\\Users\\User\\Downloads\\Book11.csv").interpolate(limit=1,limit_direction='backward')
#    Rank    Type of Train     Velocity
# 0   1.0  Aerospace Train  1200.000000
# 1   NaN     Bullet Train          NaN
# 2   3.0     Maglev Train   533.333333
# 3   4.0    Express Train   200.000000

# %%
pd.read_csv("C:\\Users\\User\\Downloads\\Book11.csv").interpolate(limit=2,limit_direction='backward')
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_11752\2852709416.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   pd.read_csv("C:\\Users\\User\\Downloads\\Book11.csv").interpolate(limit=2,limit_direction='backward')
#    Rank    Type of Train     Velocity
# 0   1.0  Aerospace Train  1200.000000
# 1   2.0     Bullet Train   866.666667
# 2   3.0     Maglev Train   533.333333
# 3   4.0    Express Train   200.000000

# %%
pd.read_csv("C:\\Users\\User\\Downloads\\Book11.csv")
# Out:
#    Rank    Type of Train  Velocity
# 0   1.0  Aerospace Train    1200.0
# 1   NaN     Bullet Train       NaN
# 2   NaN     Maglev Train       NaN
# 3   4.0    Express Train     200.0

# %%
pd.read_csv("C:\\Users\\User\\Downloads\\Book11.csv").interpolate(limit=1,limit_direction="both")
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_11752\1439420386.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   pd.read_csv("C:\\Users\\User\\Downloads\\Book11.csv").interpolate(limit=1,limit_direction="both")
#    Rank    Type of Train     Velocity
# 0   1.0  Aerospace Train  1200.000000
# 1   2.0     Bullet Train   866.666667
# 2   3.0     Maglev Train   533.333333
# 3   4.0    Express Train   200.000000

# %% [markdown]
# # limit_area: If limit is specified, consecutive NaNs will be filled with this restriction.

# %% [markdown]
# # inside: Only fill NaNs surrounded by valid values.

# %%
df.interpolate(limit_area='inside')

# %%
pd.read_csv("C:\\Users\\User\\Downloads\\Book11.csv").interpolate(limit_area='inside')
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_11752\4083270586.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   pd.read_csv("C:\\Users\\User\\Downloads\\Book11.csv").interpolate(limit_area='inside')
#    Rank    Type of Train     Velocity
# 0   1.0  Aerospace Train  1200.000000
# 1   2.0     Bullet Train   866.666667
# 2   3.0     Maglev Train   533.333333
# 3   4.0    Express Train   200.000000

# %% [markdown]
# # outside: Only fill NaNs outside valid values.

# %%
pd.read_csv("C:\\Users\\User\\Downloads\\Book11.csv").interpolate(limit_area='outside')
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_11752\3871464463.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   pd.read_csv("C:\\Users\\User\\Downloads\\Book11.csv").interpolate(limit_area='outside')
#    Rank    Type of Train  Velocity
# 0   1.0  Aerospace Train    1200.0
# 1   NaN     Bullet Train       NaN
# 2   NaN     Maglev Train       NaN
# 3   4.0    Express Train     200.0

# %% [markdown]
# # inplace: If True, the DataFrame is modified in place. If False (default), a new DataFrame is returned.

# %%
df = pd.read_csv("C:\\Users\\User\\Downloads\\Book11.csv")
df.interpolate(inplace=True)
df
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_11752\2868966153.py:2: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   df.interpolate(inplace=True)
#    Rank    Type of Train     Velocity
# 0   1.0  Aerospace Train  1200.000000
# 1   2.0     Bullet Train   866.666667
# 2   3.0     Maglev Train   533.333333
# 3   4.0    Express Train   200.000000
